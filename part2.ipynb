# %%
from disease import Disease
import requests
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import random
import obonet
import networkx as nx

# %%
disease = Disease('something', 'EFO_0000178')
disease.quantify_clustering()
# Out:
# something EFO_0000178
# No genes found for something.
# Genes: 0

# %%
def compute_clustering(diseases, filename):
    output = []
    not_included = []
    for d in diseases:
        disease = Disease(d['name'], d['efoID'])
        try:
            result = disease.quantify_clustering()
            if result is None or len(result) != 2 or any(r is None for r in result):
                not_included.append({'name' : d['name'], 'efoID' : d['efoID']})
            num_edges, z_score = result
            output.append({'name' : d['name'], 'efoID' : d['efoID'], 'num_edges' : num_edges, 'z_score' : z_score})
        except Exception as e:
            print(f"Error processing {d['name']}: {e}")
    with open(filename, 'w') as file:
        for entry in output:
            file.write(f"Name: {entry['name']}, EFO ID: {entry['efoID']}, Num Edges: {entry['num_edges']}, Z-Score: {entry['z_score']}\n")
    return output, not_included

def compare(cancerous, noncancerous, sample_size=50):
    if len(noncancerous) > sample_size:
        non_cancerous_sample = random.sample(noncancerous, sample_size)
    else:
        non_cancerous_sample = noncancerous
        
    if len(cancerous) > sample_size:
        cancerous_sample = random.sample(cancerous, sample_size)
    else:
        cancerous_sample = cancerous
        
    cancer_edges = [d['num_edges'] for d in cancerous_sample]
    non_cancer_edges = [d['num_edges'] for d in non_cancerous_sample]
    
    cancer_z = [d['z_score'] for d in cancerous_sample]
    non_cancer_z = [d['z_score'] for  d in non_cancerous_sample]
    
    t_stat, p_value = ttest_ind(cancer_edges, non_cancer_edges, equal_var=False)

    plt.boxplot([cancer_edges, non_cancer_edges], tick_labels=['Cancerous', 'Non-Cancerous'])
    plt.title(f'Clustering Comparison\np-value: {p_value:.2e}')
    plt.ylabel('Number of Edges')
    plt.show()

    print(f"True number of edges\nT-statistic: {t_stat}, P-value: {p_value}\n")
    
    t_stat, p_value = ttest_ind(cancer_z, non_cancer_z, equal_var=False)

    plt.boxplot([cancer_z, non_cancer_z], tick_labels=['Cancerous', 'Non-Cancerous'])
    plt.title(f'Clustering Comparison\np-value: {p_value:.2e}')
    plt.ylabel('Z scores for random numbers of edges')
    plt.show()

    print(f"Z scores for random numbers of edges\nT-statistic: {t_stat}, P-value: {p_value}\n")

# %%
dataPath = "data/"
url = dataPath + "www.ebi.ac.uk.txt"
efo_graph = obonet.read_obo(open(url, "r", encoding="utf8"))
allDiseases = list(set(nx.ancestors(efo_graph, "EFO:0000408")))
allCancers = list(set(nx.ancestors(efo_graph, "MONDO:0004992")))

# %%
gwasCatalogEns = pd.read_csv(
    dataPath + "gwas_catalog_v1.0.2-associations_e113_r2024-12-19.tsv",
    low_memory=False,
    sep="\t"
)

gwasCatalogEns["efoID"] = (
    gwasCatalogEns["MAPPED_TRAIT_URI"]
    .str.split("/")
    .str[-1]
    .str.replace("_", ":")
)
gwasCatalogEns["name"] = (
    gwasCatalogEns["MAPPED_TRAIT"]
)

# %%
efoID_intersection = set(gwasCatalogEns.efoID).intersection(set(allDiseases))
filtered_df = gwasCatalogEns[gwasCatalogEns['efoID'].isin(efoID_intersection)]
allDiseasesInGWAS = dict(zip(filtered_df['efoID'], filtered_df['name']))
try:
    with open("allDiseases.txt", "w") as file:
        for efo_id, name in allDiseasesInGWAS.items():
            file.write(f"{efo_id}\t{name}\n")
    print("Data successfully written to allDiseases.txt")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")
    
print(len(allDiseasesInGWAS))

# %%
efoID_intersection = set(gwasCatalogEns.efoID).intersection(set(allCancers))
filtered_df = gwasCatalogEns[gwasCatalogEns['efoID'].isin(efoID_intersection)]
allCancersInGWAS = dict(zip(filtered_df['efoID'], filtered_df['name']))
try:
    with open("allCancers.txt", "w") as file:
        for efo_id, name in allCancersInGWAS.items():
            file.write(f"{efo_id}\t{name}\n")
    print("Data successfully written to allCancers.txt")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")
    
print(len(allCancersInGWAS))

# %%
efoID_intersection = set(set(gwasCatalogEns.efoID).intersection(set(allDiseases))).difference(set(allCancers))
filtered_df = gwasCatalogEns[gwasCatalogEns['efoID'].isin(efoID_intersection)]
allNonCancersInGWAS = dict(zip(filtered_df['efoID'], filtered_df['name']))
try:
    with open("allNonCancers.txt", "w") as file:
        for efo_id, name in allNonCancersInGWAS.items():
            file.write(f"{efo_id}\t{name}\n")
    print("Data successfully written to allNonCancers.txt")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")
    
print(len(allNonCancersInGWAS))

# %%
with open("allCancers.txt", "r") as file:
    cancers = []
    for line in file:
        id, name = line.strip().split('\t')
        cancers.append({'efoID' : id.replace(":", "_"), 'name' : name})
print(len(cancers))

# %%
with open("allNonCancers.txt", "r") as file:
    noncancers = []
    for line in file:
        id, name = line.strip().split('\t')
        noncancers.append({'efoID' : id.replace(":", "_"), 'name' : name})
print(len(noncancers))

# %%
cancerous = compute_clustering(cancers, "cancerous_output.txt")

# %%
noncancerous, not_included = compute_clustering(noncancers, "noncancerous_output.txt")

# %%
print(not_included)
print(len(not_included))

# %%
import re

def read_disease_file(filename, pattern):
    with open(filename, "r") as file:
        disease_names = []
        for line in file:
            match = re.search(pattern, line)
            if match:
                name, efo_id, num_edges, z_score = match.groups()
                if num_edges != '0':
                    disease_names.append({
                        'name' : name,
                        'efo_id' : efo_id,
                        'num_edges' : int(num_edges),
                        'z_score' : float(z_score)
                        })
            else:
                print("No match:", line)
    return disease_names

# %%
pattern = r"Name:\s*(.+?),\s*EFO ID:\s*(.*?),\s*Num Edges:\s*(\d+),\s*Z-Score:\s*(-?[\d\.]+|nan+|inf)"
noncancers_names = read_disease_file("noncancerous_output.txt", pattern)
print(len(noncancers_names))

# %%
cancers_names = read_disease_file("cancerous_output.txt", pattern)
print(len(cancers_names))

# %%
print(noncancers_names)

# %%
def remove_nones(l):
    none_output = []
    to_remove = []  # Keep track of indices or items to remove

    for d in l:
        try:
            disease = Disease(d['name'], d['efo_id'])
            
            # Continue looping until the z_score is no longer infinity
            while d['z_score'] == float('inf'):
                result = disease.quantify_clustering()
                
                # If result is invalid, add to none_output and mark for removal
                if result is None or len(result) != 2 or any(r is None for r in result):
                    none_output.append({'name': d['name'], 'efoID': d['efo_id']})
                    to_remove.append(d)
                    break  # Break out of while loop to go to the next item

                num_edges, z_score = result
                d['num_edges'] = num_edges
                d['z_score'] = z_score
            
            # If num_edges is 1, remove the item
            if d['num_edges'] == 1:
                none_output.append({'name': d['name'], 'efoID': d['efo_id']})
                to_remove.append(d)

        except Exception as e:
            print(f"Error processing {d['name']}: {e}")
    
    # Filter out the items to be removed
    l = [d for d in l if d not in to_remove]
    
    return l, none_output

# %%
cancers, cancers_nones = remove_nones(cancers_names)
print(len(cancers))
print(cancers_nones)

# %%
disease = Disease('multiple sclerosis', 'MONDO_0005301')
disease.quantify_clustering()
disease.get_ppi_enrichment()
# Out:
# multiple sclerosis MONDO_0005301
# Genes mapped to multiple sclerosis: ['TSBP1', 'TSBP1-AS1', 'L3MBTL3', 'DLEU1', 'MAZ', 'MVP-DT', 'TOP3A', 'ERG', 'TNFRSF14 - PRXL2B', 'GFI1', 'CD58', 'RGS1', 'Y_RNA - CD86', 'ANKRD55', 'HLA-DQA1', 'RPL32P23 - RBM17', 'ZNF438 - LINC02664', 'TNFRSF1A', 'CLEC16A', 'CD6 - LINC02954', 'OS9', 'CDHR3 - SYPL1', 'TGFBR3', 'LINC02132 - LINC01082', 'IL2RA', 'SP140', 'RNA5SP431 - MAF', 'IL20RA - IL22RA2', 'RMI2', 'SLC2A4RG', 'GTDC1', 'LINC01967', 'TIMMDC1', 'TNFSF14', 'RGS21 - RGS1', 'JAK1', 'TYK2', 'IL7R', 'IRF1-AS1', 'IRF1', 'FAM167A', 'FAM167A-AS1', 'JAZF1', 'PHKG1', 'CYP24A1', 'MYBPC3', 'LINC01624', 'LTBR - RPL31P10', 'CD226', 'NDFIP1 - SPRY4', 'BCAS1 - CYP24A1', 'BCL6 - LINC01991', 'LINC01980', 'MCTP1', 'AFF1', 'LINC02732', 'RN7SL89P - PPA2', 'LNC-RHL1 - APOA4', 'PKIA-AS1', 'ZNF652', 'FLJ40194', 'ESPN', 'ITK', 'GARIN3', 'TNFAIP8', 'PHLDB1', 'IFITM3', 'C1orf52 - Y_RNA', 'STAT3', 'ZC3HAV1', 'SLC7A10 - CEBPA', 'CD27', 'CD27-AS1', 'HNRNPA1P41 - JAK2', 'ETV7', 'FPR1', 'POU2AF1', 'ETS1 - FLI1', 'LINC02639 - LINC02660', 'UCK2', 'HOTAIRM1', 'HOXA1', 'CDKN2B-AS1 - DMRTA1', 'ADCY3', 'SETD1A', 'SYDE2 - C1orf52', 'LZTFL1', 'SLC30A7', 'MEF2B', 'BORCS8-MEF2B', 'RNU1-150P - TTC33', 'EVI5', 'FTH1P22 - PTGFRN', 'GNG2', 'MIR3681HG', 'RGS14', 'INAVA', 'HBS1L - MYB', 'CTSH - RASGRF1', 'SLAMF1 - SETP9', 'WWOX', 'KPNB1-DT', 'EPS15L1', 'ZHX3', 'IL12A-AS1', 'Y_RNA - Y_RNA', 'VDAC
', 'TRIM14', 'RHOH - LINC02265', 'ALDH1L1', 'BCL2', 'FCRL3 - VDAC1P9', 'ZNF767P', 'LINC02102 - TENT4A', 'IFNGR2', 'RNU6-921P - ZFP36L1', 'BATF - FLVCR2-AS1', 'JADE2', 'CXCR4 - HNRNPKP2', 'CBLB', 'CBFA2T3 - ACSF3', 'IL10RB - IFNAR1', 'PTPN11', 'SERBP1P3 - RFT1', 'SGSM2', 'LINC00423 - TOMM22P3', 'TMEM8B', 'FAM221B', 'LCN6', 'RORA', 'MEF2C', 'MEF2C-AS2', 'PDE4B', 'TNIP2 - SH3BP2', 'REL-DT', 'MIR4435-2HG', 'SLA', 'TG', 'LINC01353 - BTG2-DT', 'RASGEF1A', 'MINK1', 'AKAP13', 'LINC02644 - ZNF438', 'MYO5B', 'LINC00708 - KRT8P37', 'IKZF2 - LINC01953', 'NAB1', 'ENTHD1 - GRAP2', 'EXOC2', 'CASP8', 'UNK', 'SMARCA4', 'LINC01063 - NRROS', 'ANKRD36BP2', 'COG6', 'TMEM244 - L3MBTL3', 'RGCC', 'RNU6-919P - SLC9A8', 'RPS6KA5', 'ZBTB38', 'LINC02940 - RPL23AP12', 'RPL1 ...
# Genes: 468
#
# Proteins: 248
#
# Number of edges: 165
#
# P-value: 0.0
# '0.0'

# %%
print(len(noncancers_names))
noncancers, noncancers_nones = remove_nones(noncancers_names)
print(len(noncancers))
print(noncancers_nones)

# %%
with open('cancerous_final.txt', 'w') as file:
        for entry in cancers:
            file.write(f"Name: {entry['name']}, EFO ID: {entry['efo_id']}, Num Edges: {entry['num_edges']}, Z-Score: {entry['z_score']}\n")

# %%
with open('noncancerous_final.txt', 'w') as file:
        for entry in noncancers:
            file.write(f"Name: {entry['name']}, EFO ID: {entry['efo_id']}, Num Edges: {entry['num_edges']}, Z-Score: {entry['z_score']}\n")

# %%
compare(cancers, noncancers, len(cancers))

# %%
def get_pvalue(l):
    for d in l:
        d['pvalue'] = None
        disease = Disease(d['name'], d['efo_id'])
        disease.quantify_clustering()
        try:
            pvalue = disease.get_ppi_enrichment()
        except Exception as e:
                print(f"Error processing {d['name']}: {e}")
        d['pvalue'] = pvalue
    return l

# %%
pattern = r"Name:\s*(.+?),\s*EFO ID:\s*(.*?),\s*Num Edges:\s*(\d+),\s*Z-Score:\s*(-?[\d\.]+|nan+|inf)"
noncancers = read_disease_file("noncancerous_final.txt", pattern)
print(len(noncancers))
# Out:
# 446

# %%
pattern = r"Name:\s*(.+?),\s*EFO ID:\s*(.*?),\s*Num Edges:\s*(\d+),\s*Z-Score:\s*(-?[\d\.]+|nan+|inf)"
cancers = read_disease_file("cancerous_final.txt", pattern)
print(len(cancers))
# Out:
# 57

# %%
cancers = get_pvalue(cancers)
# Out:
# carrier status, prostate carcinoma EFO_0001663
# Genes mapped to carrier status, prostate carcinoma: ['GARIN3P1 - CAAP1', 'CASC17', 'CASC19', 'PRNCR1', 'PCAT1', 'NAV1', 'IPO9-AS1']
# Genes: 7
#
# Proteins: 1
#
# Number of edges: 42
#
# P-value: 7.05e-14
# esophageal carcinoma EFO_0002916
# Genes mapped to esophageal carcinoma: ['ALDH2', 'ADH1B', 'PLCE1', 'CHEK2', 'ADH4', 'PSMB3P2 - IGFBP2', 'ATP6V1G1P7 - RPL7P45', 'HECTD4', 'CSNK1A1', 'NAALADL2 - ACTG1P23', 'SEMA5B', 'CARS1P1 - ANP32A', 'PDE4D', 'ACAD10', 'RUNX1', 'LRFN2 - UNC5CL', 'LINC00160 - LINC01426', 'RASSF10 - BMAL1', 'IFT81 - ATP2A2', 'CASP8', 'FLACC1']
# Genes: 21
#
# Proteins: 13
#
# Number of edges: 2
#
# P-value: 0.0819
# squamous cell carcinoma EFO_0000707
# Genes mapped to squamous cell carcinoma: ['BRCA2', 'CHEK2', 'SLC45A2', 'ANKRD11', 'CDYL - RPP40', 'MICA - LINC01149', 'LPP', 'FLACC1', 'CASP8', 'TRPS1', 'UBAC2 - CCR12P', 'DTNBP1', 'HERC2', 'SEC16A', 'BACH2', 'BNC2 - RN7SL720P', 'HLA-DRB1 - HLA-DQA1', 'KRT5', 'TYR', 'OCA2', 'TPM3P2 - PIGPP3', 'MC1R', 'IRF4', 'DEF8', 'PRKN', 'SRC', 'ST3GAL1', 'ERBIN', 'DNAH11', 'LRFN2', 'RALY', 'FOXP1', 'TPRG1 - TP63', 'HLA-DQA1', 'RPS6P15 - GPAM', 'SPATA33', 'DYNLRB2-AS1', 'CYP1B1', 'LINC00886', 'ADAMTS12 - RXFP3', 'PPARGC1B', 'DUSP22 - IRF4', 'AHR', 'LURAP1L-AS1', 'BNC2', 'CDKN2B-AS1', 'LINC02674 - RAB11FIP2', 'TPCN2', 'TYR - NOX4', 'SUOX - IKZF4', 'HAL', 'ATP11A', 'MARK3', 'FRMD5', 'GAS8', 'TGM3', 'EPB41L1', 'RCC2', 'SLC6A17', 'CTSS - CTSK']
# Genes: 60
#
# Proteins: 42
#
# Number of edges: 15
#
# P-value: 8.39e-08
# lung adenocarcinoma EFO_0000571
# Genes mapped to lung adenocarcinoma: ['TP63', 'TERT', 'HLA-DPB1 - HLA-DPA2', 'BTNL2', 'TSBP1-AS1', 'BPTF', 'FOXP4-AS1', 'ACTR2', 'AQP7 - AQP3', 'SECISBP2L - COPS2', 'TERC', 'BAZ1A', 'TPRG1 - TP63', 'CLPTM1L', 'DCBLD1', 'NRG1', 'RN7SL151P - MTAP', 'VTI1A', 'MPZL3', 'UBXN4', 'LINC00399 - LINC00676', 'PHLDB1', 'MUSK - LPAR1', 'CYP2A6', 'MCCD1P1', 'IFITM4P - HLA-V', 'CYP1A1 - CYP1A2', 'CHRNA5', 'CALCRL-AS1', 'TFPI', 'RPS2P18 - CDCA7', 'RN7SKP277 - PNPT1P2', 'MRPS18BP2 - RPL9P13', 'CCDC85C - HHIPL1', 'GALK2', 'LINC02562 - LINC02483', 'FAM227B', 'FGF7', 'TEKT5', 'MORF4L1', 'MIGA1', 'PDE3A', 'CABLES1', 'CNTLN', 'RPS19P6 - RPS20P25', 'LINC02831 - LINC01812', 'LINC02789', 'DCTN4', 'RNA5SP173 - NDUFB5P1', 'NKD2 - SLC12A7', 'LINC01829', 'LINC01828', 'THORLNC - LINC01956', 'DTWD1 - ATP8B4', 'LINC00824', 'SSC5D - SBK2', 'RPL10L - MDGA2', 'EPHX2 - GULOP', 'LINC00511', 'UBE4A', 'PDCD6P1', 'FUT2', 'RNASET2 - MIR3939', 'ACTRT3 - MYNN', 'LMBR1 - NOM1', 'IRF4', 'RAB31', 'CD83P1 - RNU6-471P', 'NUMBL', 'PVT1', 'NCOA1', 'TLE3 - RNU6-745P', 'ARHGEF34P - OR2A9P', 'NAF1', 'SLC52A1', 'HSD17B2-AS1', 'RASSF3', 'SBF2', 'EGFR', 'TRMT9B - RNU6-842P', 'MPZL2', 'ACTR2 - SPRED2', 'PGR-AS1 - TRPC6', 'LPCAT1', 'CNTNAP2', 'ADCY1', 'MICAL2 - PARVA', 'LRFN1 - GMFG', 'GIPC2 - RNFT1P2', 'ADAMTS7', 'ETAA1 - LINC02831', 'STN1 - SLK', 'CEACAM21 - CEACAMP3', 'GIPC2', 'DNAJB4', 'MTAP', 'CDKN2B-AS1', 'AK5', 'CHRNB4', 'CCDC26', 'ZZZ3', 'APOM', 'CHRNA3', 'NOP56P1 - LINC01623', 'CDKN2B-AS1 - DMRTA1', 'ACVR1B', 'SYNGR2', 'MTUS1', 'PSMA4 - CHRNA5', 'MIR4457 - CLPTM1L', 'SECISBP2L', 'RTEL1-TNFRSF6B', 'RTEL1', 'MICG - HLA-G', 'POT1-AS1', 'MIR4454 - NAF1', 'SDHDP3 - RNU6-637P', 'C11orf65', 'ATM', 'TSBP1-AS1 - HLA-DRA', 'PIK3CB - ATP5MC1P3', 'DTNB', 'FADS2', 'FADS1', 'FAM53B', 'RNU6-102P - GPR37', 'GCLC', 'PALM', 'RFX7', 'LINC02475 - KCTD8', 'PDGFC - RPPH1-3P', 'SFTPB', 'GAREM1']
# Genes: 133
#
# Proteins: 67
#
# Number of edges: 19
#
# P-value: 2.11e-06
# multiple myeloma EFO_0001378
# Genes mapped to multiple myeloma: ['ARMC9', 'MYNN', 'PSORS1C1', 'MXI1', 'TNFRSF13B', 'CBX7', 'DTNB', 'POU5F1', 'DNAH11', 'GRIP1', 'SMASR', 'TBCA - AP3B1', 'RNU7-152P - MIR1202', 'HCG27', 'IGFBPL1 - ARMC8P1', 'KANK1', 'RN7SL332P - JARID2-DT', 'ATG5', 'SMARCD3', 'CASC19', 'PCAT1', 'CDKN2A', 'WAC', 'RFWD3', 'PREX1', 'ULK4', 'LRRC34', 'CCHCR1', 'ELL2', 'TOM1', 'CCSER1', 'RN7SL366P - C6orf118', 'LARP1BP2 - CCDC71L', 'RP1', 'SOHLH2', 'CCDC169-SOHLH2', 'SRCAP', 'HSPE1P1 - LINC01370', 'TNKS', 'PPP1R3B-DT - TNKS', 'CCND1', 'LINC01411', 'MECOM', 'ANO5', 'DIO1', 'MED24', 'MIR124-1HG - MSRA-DT', 'YWHAQP1 - TUBBP3', 'RBP5', 'LCOR', 'CDH13', 'PSME2P2 - FNDC3A', 'OTX2-AS1', 'POLQ', 'RNU6-637P - TERC', 'RNA5SP267 - SLC2A13P1', 'ILF2', 'HERC2', 'LINC02269', 'RNA5SP173 - NDUFB5P1', 'LINC02622 - UNC5B', 'RPL31P9 - DSEL', 'AKAP7', 'MANCR', 'CDH12', 'ANKRD11', 'PPIAP66 - RPL5P7', 'NDUFB4P4 - KIF3C', 'USP8P1', 'COTL1P1 - TBC1D27P', 'FUNDC2P4 - PDGFB', 'SP3', 'CEP120', 'POT1-AS1', 'RNU6-416P - SRCAP', 'KLF2', 'IRF4', 'LINC00928 - TICRR', 'HGF - CACNA2D1', 'ULK4 - GEMIN2P2', 'CHPF2', 'PHC3', 'NFIC', 'LINC02872 - DAPK1', 'LINC02652 - WAC-AS1', 'STN1 - SLK', 'H3C9P - BTN3A2', 'SAMSN1', 'SP3 - LINC01960', 'LINC01485 - CPEB4', 'BRCA2']
# Genes: 91
#
# Proteins: 51
#
# Number of edges: 12
#
# P-value: 2.35e-05
# myeloproliferative disorder EFO_0004251
# Genes mapped to myeloproliferative disorder: ['JAK2', 'LINC02082 - LINC01997', 'HBS1L - MYB', 'LINC01565 - RPN1', 'IL12A-AS1', 'KPNA4 - KRT8P12', 'MECOM', 'CXXC4-AS1 - RPL6P14', 'TERT', 'RPL35P2 - NUDT3', 'LINC-PINT', 'GFI1B - EEF1A1P5', 'ATM', 'SH2B3', 'MRPS31', 'ZNF521', 'RUNX1', 'CHEK2', 'FOXO1', 'TCL1A - TUNAR', 'LINC00523 - DLK1', 'TNFSF13', 'TNFSF12-TNFSF13', 'FAM117A', 'LINC01478', 'BCL2', 'BCL2L1 - TPX2', 'SNTA1', 'PMF1', 'PMF1-BGLAP', 'YBX1P9 - PARP1', 'TRIM58', 'GACAT3 - CYRIA', 'CXCR4 - HNRNPKP2', 'SENP7', 'LINC01214 - TSC22D2', 'MYNN', 'MIR4454 - NAF1', 'POLR2LP1 - CCHCR1', 'CCDC162P', 'MAD1L1', 'RPL15P11 - STMP1', 'RBPMS', 'SPATA6L', 'STN1', 'ATXN2']
# Genes: 46
#
# Proteins: 25
#
# Number of edges: 11
#
# P-value: 3.2e-05
# non-small cell lung carcinoma EFO_0003060
# Genes mapped to non-small cell lung carcinoma: ['RN7SL151P - MTAP', 'TPRG1 - TP63', 'BAZ1A', 'VTI1A', 'TERT', 'FOXP4-AS1', 'TERC', 'MCCD1P1', 'CASP8', 'NRG1', 'MPZL3', 'CHRNA5', 'CYP2A6', 'CLPTM1L', 'AQP7 - AQP3', 'BRCA2', 'APOM', 'TP63', 'SECISBP2L - COPS2', 'MSH5-SAPCD1', 'MSH5', 'AK5', 'GTF2H4', 'FAM114A1', 'IFITM4P - HLA-V', 'UBXN4', 'CYP1A1 - CYP1A2', 'BBS7-DT - TRPC3', 'PHLDB1', 'MUSK - LPAR1', 'NLRP1 - WSCD1', 'LAMA1', 'XXYLT1', 'PIEZO2', 'SLC17A8 - NR1H4', 'EIF4E2', 'DSCAM', 'LINC00114 - ETS2', 'HADHB - ADGRF3', 'ALDH1A2', 'SAXO1', 'CPS1 - RPS27P10', 'MIER2 - SPMAP2', 'LINC02462 - EEF1A1P35', 'ANKS1A', 'DLST', 'THSD7B', 'NCOA2', 'CDH8', 'NALCN', 'SLC35D2', 'MUC3A', 'C13orf42 - FAM124A', 'LINC02223', 'FUCA2 - PHACTR2', 'MSRB3', 'BEGAIN', 'RNU6-745P - LINC02205', 'MAGI2', 'RPS3AP17 - PCDH7', 'DAPK1', 'GRIK3 - MIR4255', 'LINC03093 - GFRA2', 'LRRK1 - CHSY1', 'LINC01492 - RNA5SP291', 'MTND6P25 - MIR4300HG', 'NEBL', 'NKAIN2', 'FXYD3', 'NCS1 - HMCN2', 'KAZN', 'ARG1', 'CALML5 - CALML3-AS1', 'HMGN2P17 - CA6', 'SINHCAF']
# Genes: 75
#
# Proteins: 44
#
# Number of edges: 5
#
# P-value: 0.032
# triple-negative breast cancer EFO_0005537
# Genes mapped to triple-negative breast cancer: ['MDM4', 'TERT', 'CCDC170', 'ANKLE1', 'PTHLH - CCDC91', 'LINC01956', 'ANKLE1 - ABHD8']
# Genes: 7
#
# Proteins: 4
#
# Number of edges: 0
#
# P-value: 1.0
# mammographic density measurement EFO_0005941
# Genes mapped to mammographic density measurement: ['YWHAQ - RNU4-73P', 'ADD2', 'AFF3', 'MAPK10-AS1', 'MAPK10', 'BTBD9', 'FAF1', 'LINC01376', 'TET3 - FNBP1P1', 'DIRC3', 'PPARG', 'RBM48P1 - Y_RNA', 'BOLA3P3 - HSPE1P10', 'ATXN1', 'LINC02680 - MKX', 'PRKG1', 'RPL21P94 - GVINP1', 'ITPR2-AS1', 'SSPN', 'RAD51B', 'BCL2', 'FUT2', 'PELATON', 'NBEA - LINC00445', 'LINC01579', 'RPL17P33 - LINC00589', 'MDS2', 'SPAG17 - RNA5SP56', 'TBX15', 'ADCY3', 'LINC01101 - Y_RNA', 'ADAMTS9-AS2', 'LY86 - BTF3P7', 'ZNF365', 'BMAL1', 'ADAMTS8', 'PGAM1P5', 'ADAMTSL3', 'ZNF365 - LINC02929']
# Genes: 39
#
# Proteins: 18
#
# Number of edges: 1
#
# P-value: 0.5139
# estrogen receptor status EFO_0005512
# Genes mapped to estrogen receptor status: ['FGFR2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 16
#
# P-value: 0.0762
# endometrial carcinoma EFO_1001512
# Genes mapped to endometrial carcinoma: ['RNY1P8 - MARK2P12', 'HEY2-AS1', 'LINC02523', 'LINC00824 - CCDC26', 'EIF2AK4', 'AKT1', 'HNF1B', 'MIR4713HG', 'CYP19A1', 'LINC00824', 'BOLA2P3 - CASC15', 'FYB2', 'NGF-AS1 - ELOCP20', 'KIF26B', 'CCDC85A', 'RN7SL553P - MTARC2P1', 'STX18-AS1', 'IGBP1P5 - RN7SL101P', 'RNF150', 'LY86-AS1', 'LY86', 'H4C8 - H3C9P', 'MDN1', 'CASP8AP2', 'CCDC185 - CAPN8', 'RNA5SP189 - LINC01950', 'LHFPL3', 'CDKN2B-AS1', 'BANP - LINC02182', 'RNA5SP231 - RNU6-832P', 'RPL31P3 - HAUS6P2', 'GINS2', 'TLE1', 'NTM', 'CDKN2B-AS1 - DMRTA1', 'WT1-AS', 'ITPR2-AS1', 'SSPN', 'NAV3', 'SH2B3', 'ATXN2', 'TBX3-AS1 - UBA52P7', 'EVI2A', 'NF1', 'SKAP1', 'BPTF', 'GATA6 - CTAGE1', 'LINC01427 - LINC00261', 'NCAM2', 'LINC01256 - PCDH10-DT', 'ID4 - RPL29P17', 'DLC1 - SGCZ', 'EXT1', 'LINC02451', 'LINC02331', 'CSMD2', 'GNL2 - RSPO1', 'RNU6-1304P - SRP9', 'BCL11A', 'RN7SL361P - IFITM3P9', 'PPARG', 'EEFSEC', 'PPP1R14C', 'ZKSCAN5', 'PLPPR4', 'LINC03003', 'CPVL', 'PTPRD', 'FCHSD2', 'RPL6P25 - SLC6A15']
# Genes: 70
#
# Proteins: 35
#
# Number of edges: 5
#
# P-value: 0.0153
# squamous cell lung carcinoma EFO_0000708
# Genes mapped to squamous cell lung carcinoma: ['MORN5', 'TPRG1 - TP63', 'CHRNA5', 'RAD52', 'MCCD1P1', 'HLA-B', 'MSH5-SAPCD1', 'MSH5', 'GTF2H4', 'PRAG1', 'BRCA2', 'APOM', 'HCP5', 'CLPTM1L', 'BBS7-DT - TRPC3', 'PDS5B', 'LINC01148 - LINC02296', 'RNU6-67P - SLITRK1', 'NPAS3', 'CATSPER2', 'CHRNA3', 'CHRNB4', 'GOLGA6GP', 'MORF4L1', 'KRT18P47 - CARMAL', 'ELAC2 - LINC02093', 'KRT41P - KRT37', 'LINC01987 - LINC01973', 'LINC01478', 'CYP2A6', 'ZSCAN12', 'PPP1R9A-AS1', 'PPP1R9A', 'MAD1L1', 'LINC01556 - KRT18P1', 'RPL31P37 - FEZF1', 'POT1-AS1 - GRM8', 'HDAC9', 'RN7SL292P - SGO1P2', 'CNTNAP2', 'CICP20 - RNU6-326P', 'SEMA3C - EIF4EP4', 'BSNDP4 - RNU6-417P', 'ACTR3B - LINC01287', 'RUNDC3B', 'ABCB1', 'MKLN1', 'CYCSP19 - RN7SKP277', 'PSMC1P3 - CHRM2', 'ZP3P2 - PSMC1P3', 'NUP42 - GPNMB', 'ZNF92 - LINC03006', 'RNF138P2 - RNU1-14P', 'DPP6', 'WDR91 - STRA8', 'MTND4P3 - RNA5SP231', 'RNU4-66P - RIMS1', 'LINC-PINT', 'CDCA7L - RAPGEF5', 'COBL', 'AP1S2P1 - RN7SKP104', 'LINC02055', 'ZNF623', 'ECPAS', 'PBX3', 'REXO4', 'DBH', 'CDKN2B-AS1', 'GLIS3', 'ERLIN1 - CHUK', 'PKD2L1', 'MASTL', 'AKR1C6P - U8', 'NPFFR1', 'CHEK1', 'H19', 'PANX1', 'WNK1', 'LINC00343', 'TEX29 - LINC02337', 'FRY', 'ADAR - KCNN3', 'DCAF8', 'QRSL1P1 - XCL2', 'LINC01774 - TFDP1P1', 'EDN2 - HIVEP3', 'KDM4A-AS1', 'KDM4A', 'LINC01712', 'LRRC8D', 'NEB', 'VSNL1', 'LINC01953 - SPAG16-DT', 'NYAP2 - MIR5702', 'SRBD1', 'RNA5SP144 - LARP7P4', 'ABCG2', 'GNPDA1 - NDFIP1', 'HMGN3-AS1 - Y_RNA', 'HCN1 - EMB', 'XRCC4', 'TFAP2A', 'TFAP2A-AS1', 'HNRNPA1P58 - NRSN1', 'CARMIL1', 'SCGN', 'H2AC6', 'H3C9P - BTN3A2', 'BTN3A3', 'ZNF322', 'MIR3143 - RPL10P2', 'VN1R10P - ZNF204P', 'ZNF184 - HNRNPA1P1', 'CD83P1 - RNU6-471P', 'OR2B2 - OR2W6P', 'ZSCAN16-AS1', 'PGBD1', 'SUMO2P1 - MOG', 'CHEK2', 'CHUK-DT', 'CHRNA4', 'LINC01149 - HCP5', 'PTK2B', 'ANKLE1 - ABHD8', 'HLA-DQB1', 'LINC01122', 'IKZF2']
# Genes: 127
#
# Proteins: 61
#
# Number of edges: 21
#
# P-value: 2.29e-09
# gastric carcinoma EFO_0000178
# Genes mapped to gastric carcinoma: ['MUC1; MTX1; THBS3', 'GBAP1', 'JRK', 'PSCA', 'TTC33', 'PTGER4', 'MUC1', 'OPCML', 'PRKAA1', 'OARD1', 'UNC5CL', 'NPIPB2', 'THBS3-AS1', 'THBS3', 'GON4L', 'LMNA', 'HNRNPA1P57 - LDHAP3', 'LINC02580', 'TATDN2', 'LINC02516', 'MYL12BP2 - LINC02363', 'TERT - MIR4457', 'C7', 'VN1R10P - ZNF204P', 'ZKSCAN8P1 - ZNF603P', 'PGBD1 - SMIM15P2', 'MAS1LP1', 'HLA-F', 'HLA-U - HLA-A', 'PPP1R10', 'HLA-S - MICA', 'LRFN2 - UNC5CL', 'MRM3P2 - PRPS1L1', 'KCNU1', 'MROH4P - ARC', 'PSCA - LY6K', 'SMARCA2', 'RANBP6 - GTF3AP1', 'VN1R53P - TACC1P1', 'PLCE1', 'LINC02388 - LRIG3', 'LINC01068 - LINC01038', 'BRMS1L - ILF2P2', 'CHST14 - CCDC32', 'VPS35L', 'SNAP25-AS1', 'ZBTB20', 'ASH1L', 'LINC02161', 'ARL4C - LINC01173', 'MTX1', 'RNU6-309P - GAPDHP77', 'KRTCAP2', 'NSUN3 - ARMC10P1', 'FGF18 - SMIM23', 'RPL3P2 - WASF5P', 'HIGD1AP2 - PTMAP5', 'HLA-C', 'MLN - LINC01016', 'ABO', 'CUX2', 'DEFB121', 'ALK', 'HNF1B']
# Genes: 64
#
# Proteins: 31
#
# Number of edges: 5
#
# P-value: 0.00023
# estrogen-receptor negative breast cancer EFO_1000650
# Genes mapped to estrogen-receptor negative breast cancer: ['LGR6', 'MDM4', 'PEX14', 'LINC01376', 'RALB - INHBB', 'TERT', 'TERT - MIR4457', 'CCDC170', 'CCDC170 - ESR1', 'ZNF365 - LINC02929', 'LSP1', 'PTHLH - CCDC91', 'CASC16', 'FTO', 'ANKLE1', 'BABAM1', 'USHBP1', 'WDR43', 'PPIL3', 'RNY1P8 - MARK2P12', 'CDKN2B-AS1', 'PGAM1P5', 'BRCA2', 'LINC02929', 'ANKLE1 - ABHD8', 'ADCY9', 'L3MBTL3', 'POGLUT3', 'PA2G4P3 - CDH2', 'C19orf12 - CCNE1', 'ANXA13 - FAM91A1', 'RPL23AP53 - ZNF596', 'GAREM1', 'DIRC3-AS1', 'RAD51B', 'ESR1', 'RIN3', 'RPS27P20 - LINC01395', 'POU5F1B', 'CASC8', 'PCAT1', 'KCNU1 - SMARCE1P4', 'EBF1', 'DIRC3', 'RPSAP72 - TENT5A', 'FLACC1', 'CASP8', 'HNF4G', 'KCNN4 - LYPD5', 'ELL', 'LINC01101 - Y_RNA', 'MRTFA', 'C5orf67 - MAP3K1', 'TCF7L2', 'TNFSF10 - LINC02068', 'KCNK2 - VDAC1P10', 'KCNK2', 'SPDYE12 - CASTOR2', 'LINC01956']
# Genes: 59
#
# Proteins: 29
#
# Number of edges: 8
#
# P-value: 0.0003
# cervical carcinoma EFO_0001061
# Genes mapped to cervical carcinoma: ['HLA-DRB1 - HLA-DQA1', 'TCF7L1', 'LUCAT1', 'ADGRV1', 'LINC01445', 'GTF3AP6 - LINC02476', 'ZPBP2 - GSDMB', 'TMEM233', 'LINC00540', 'LINC00460 - RPL35P9', 'TTC5', 'TEP1', 'LRFN5', 'MEG9', 'RBFOX1', 'LINC02097', 'SOX9-AS1', 'RN7SL836P - GIPR', 'HAS1 - FPR1', 'RASSF2', 'MYT1', 'NPBWR2', 'HLA-E - LINC02569', 'TUBB', 'INS-IGF2', 'IGF2', 'UHMK1', 'DDR2', 'NPM1P48 - LINC01249', 'NRXN1', 'ALMS1', 'LINC01918 - GPR45', 'PRPS1P1 - CYP2C56P', 'FSIP2 - RPL21P32', 'NYAP2 - MIR5702', 'GBE1 - LINC02008', 'NMNAT1P3 - CLDN1', 'ZFYVE28', 'CAMK2D', 'TTC29', 'RPL8P1 - LINC01012', 'H3C10 - H2AC14', 'ZSCAN16-AS1', 'ZSCAN31', 'ZKSCAN3', 'OR2E1P - GPX6', 'SCAND3 - LINC00533', 'NOP56P1 - LINC01623', 'ZNF311 - OR2AD1P', 'LINC03003', 'SUMO2P1 - MOG', 'HLA-G', 'RNF39', 'LINC00243', 'NAPGP2 - MUC21', 'LINC02571 - HLA-B', 'NFKBIL1 - LTA', 'VWA7', 'STK19', 'TNXB', 'NOTCH4 - TSBP1-AS1', 'HLA-DRB9 - HLA-DRB5', 'MTCO3P1 - HLA-DQB3', 'HLA-Z - HLA-DMB', 'COL11A2P1 - HLA-DPB2', 'RN7SL564P - FABP7', 'ATXN7L1', 'EXOC4', 'RPS3AP27', 'TNKS - MIR124-1HG', 'CHCHD7 - SDR16C5', 'TOX-DT - RNA5SP267', 'PRUNE2', 'PCA3', 'TRDMT1', 'OR5B1P', 'TMTC1', 'RAB22A - VAPB', 'HCG27 - HLA-C', 'SAPCD1', 'MSH5-SAPCD1', 'PTBP3', 'FCRL4', 'HDAC11 - FBLN2', 'MICB - PPIAP9', 'GABRB1', 'TBXAS1', 'LINC02950 - RN7SL178P', 'SULF1 - SLCO5A1', 'SUGT1P3 - ELF1', 'LINC03080 - RPL7P5', 'LINC02582 - RN7SL401P', 'LTA', 'HLA-DQA1', 'MICA - LINC01149', 'HLA-DPB2', 'RPL21P119 - LINC02177', 'LZTS1 - TMEM97P2', 'KBTBD11 - MYOM2', 'ZNF804B', 'C2orf83', 'GSAP - GCNT1P5', 'INSIG2 - THORLNC', 'LINC01899 - CBLN2', 'SLAMF7 - LY9', 'EXOC1', 'COL11A2P1', 'ZNF70P1 - HTATSF1P1', 'ARMH3', 'PAX8', 'PAX8-AS1', 'HLA-DQA2', 'MICA', 'PBX2', 'PRRC2A', 'MUC22', 'TTC34 - ACTRT2', 'ACACB', 'LINC01149']
# Genes: 119
#
# Proteins: 52
#
# Number of edges: 8
#
# P-value: 5.5e-06
# pancreatic carcinoma EFO_0002618
# Genes mapped to pancreatic carcinoma: ['LINC01829', 'SEC11C - GRP', 'HNF1A', 'WNT2B', 'LINC01620', 'ROR1', 'ABO', 'RNY1P8 - MARK2P12', 'NR5A2', 'CLPTM1L', 'LINC-PINT', 'PLUT - PDX1', 'LINC00511', 'ETAA1 - LINC02831', 'SUGCT', 'TP63', 'PLUT', 'AGT', 'PRMT5P1 - EDNRA', 'PNMT', 'HNF1B', 'IGFBP4 - TNS4', 'SMC2', 'MED24', 'THRA', 'LINC01081 - LINC00917', 'MICAL3', 'ARL6IP6 - UBQLN4P2', 'TNS4', 'NOC2L', 'TNS3', 'HNF4G', 'ZNRF3', 'CASC11', 'RNU6-609P - NR5A2', 'BCAR1', 'TERT - MIR4457', 'TERT', 'LINC00824', 'LINC03094 - SMC2-DT', 'C12orf43 - OASL', 'ZNF429 - MTDHP3', 'ARRDC5', 'LINC01173', 'DPP6', 'LINC01394 - FOXF2-DT', 'ANXA13 - FAM91A1', 'LINC01114 - PANTR1', 'LINC01068 - LINC01038', 'PRPSAP2', 'RNF5P1 - TACC1', 'CTD-2194D22.4 - Y_RNA', 'BICD1', 'MYO1D', 'PRKN', 'RNF149', 'RNF43', 'TSPOAP1-AS1', 'THSD7B', 'LINC01052', 'RNU7-152P - MIR1202', 'TFRC', 'BACH1', 'DAB2', 'LINC00867 - SLC25A18P1', 'LINC02549 - ADGRB3-DT', 'RNU6-694P - SLC1A1', 'TFF2 - TFF1', 'TAFA5', 'KRT18P32 - MIPEPP2', 'LDLRAD4', 'CRBN - SUMF1', 'DELEC1', 'GRID1', 'GTF2H1', 'LINC00376 - LINC00395', 'SBF2', 'RNU6-778P - RNU6-716P', 'ST7L', 'ITGA3', 'ABLIM2', 'CIMIP1 - ANKRD60', 'LINC01824 - MIR7515HG', 'MIR4431 - ASB3', 'POLA2', 'SATB1-AS1 - RNU6-138P', 'LINC02873 - PPP1R10P1', 'OR5K1', 'ZSCAN5A', 'EDDM13', 'PKN1', 'DOK2', 'APOB', 'MIR182 - MIR96', 'RPL23AP54 - RN7SKP159', 'RNA5SP443 - ARHGAP27', 'TIPINP2 - CFAP20', 'CCDC68', 'ANKRD27', 'CIMIP4', 'LINC01249 - RNU6-649P', 'RFTN2', 'CAV2', 'SAG', 'IQCA1 - ACKR3', 'COLQ', 'LINC02260 - KIT', 'TARS1', 'GPSM3', 'DST', 'SAMD12-AS1', 'TRPM3', 'SOHLH1', 'RASSF10 - BMAL1', 'PRMT3', 'NCAPD3', 'NACA', 'DDX54', 'MARK3 - CKB', 'SNRNP25', 'CACNA1H', 'SRGAP1', 'KRT8', 'LINC01147']
# Genes: 124
#
# Proteins: 68
#
# Number of edges: 14
#
# P-value: 0.00027
# gastric cardia carcinoma EFO_1001252
# Genes mapped to gastric cardia carcinoma: ['PRKAA1']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 52
#
# P-value: 0.0
# age at onset, glioblastoma multiforme EFO_0000519
# Genes mapped to age at onset, glioblastoma multiforme: ['TERT', 'SEC61G-DT - EGFR', 'EGFR', 'CDKN2B-AS1', 'TP53', 'RTEL1-TNFRSF6B', 'RTEL1', 'CCDC26']
# Genes: 8
#
# Proteins: 4
#
# Number of edges: 3
#
# P-value: 0.112
# ovarian carcinoma EFO_0001075
# Genes mapped to ovarian carcinoma: ['TERT', 'HNF1B', 'PLEKHM1', 'SKAP1', 'USHBP1', 'BABAM1', 'METTL15P1 - LINC00886', 'BNC2 - RN7SL720P', 'HAGLR', 'HAGLROS', 'RSPO1', 'TTC28', 'PVT1', 'HNF1A-AS1', 'CCT6P4 - ENAHP1', 'TRIM61 - RPL21P51', 'HOXD3', 'SYNPO2', 'LINC00824', 'RCCD1 - PRC1', 'ATAD5', 'ACOXL', 'MIR4435-2HG', 'GPX6', 'LAMA3', 'PDCL2P1 - PTCHD1', 'LINC01924 - LINC01916', 'LINC01898 - LINC01893', 'RPL3 - SYNGR1', 'LINC02183', 'BRCA1', 'WARS2-AS1 - LINC01780', 'NYAP2 - MIR5702', 'LINC01237', 'MARCHF1', 'ADAMTS16', 'HMHB1 - RN7SL87P', 'AARS2 - SPATS1', 'ADGB', 'ZNF804B - RNU6-274P', 'GABBR2', 'FRMPD2', 'LHFPL6', 'LINC02165 - PPIAP48', 'SMPD3', 'RPL35AP33 - ZFP90', 'MSI2', 'ASXL3', 'PPIAP7 - LINC01307', 'DNM3', 'MIR548AE1 - ZNF804A', 'PARD3B - NRP2', 'SAMMSON', 'MDFIC2', 'TNIK', 'SORBS2', 'CXXC5 - RNU6-236P', 'LINC03054 - CLXN', 'PBX3 - MVB12B', 'TPTE2P3', 'MTHFD1', 'CPDP1 - LGALS9DP', 'ABCA10', 'TIPARP', 'WNT4 - MIR4418', 'LUZP2 - RPL36AP40', 'NSF', 'ANKLE1', 'CHMP4C', 'MLLT10', 'BRIP1', 'LRRC47', 'MTCO1P21 - ABCA4', 'LMNA', 'KDM3A', 'RPS20P14 - RPL29P9', 'RNU6-525P - CNOT6', 'TFAP2A', 'FANCE', 'UFL1-AS1', 'PKD1L1', 'DAPK1', 'OLFM1 - LINC02907', 'ATRNL1', 'PRANCR', 'CNOT2', 'CNOT2 - KCNMB4', 'LINC02183 - CRNDE', 'IRX6 - RPL31P56', 'NLRP1 - WSCD1', 'ZNF274', 'TFAP2C - RNU6-1146P', 'RNU7-157P - MIR3147HG', 'PTPRZ1', 'PRKAG2', 'TONSL', 'PHF24', 'CTR9', 'CTNND1', 'RPUSD4', 'LINC02405 - LINC02376', 'HAP1', 'RPS27AP20 - RPL24P9', 'SLC22A23 - PXDC1', 'SPCS3 - HAFML', 'HS6ST3', 'SMUG1P1 - ACAA2', 'LINC01818 - RND3', 'JAZF1', 'RNU6-92P - ST13P7', 'LRPPRC - RNU6-566P', 'MIRLET7BHG - PPARA', 'PA2G4P2 - LINC01722', 'ASAH1-AS1 - NAT1', 'KRT18P55', 'SMIM15P1 - PINCR', 'ADARB2', 'LINC00200', 'NUP153', 'CCDC80', 'LINC02652', 'UBE2G1', 'CASC8 - CASC11', 'LINC02817 - DUSP10', 'RN7SKP112 - LINC02973', 'TRIM2', 'THSD7A', 'GABRG3', 'GABRG3-AS1', 'EIF4G3', 'NCAM2', 'LINC01228 - DYNLRB2-AS1', 'SLCO4C1 - RN7SKP68', 'RPS20P25 - TLE1', 'FAM3C2P - PDCL2P1', 'LINC02655', 'NPSR1-AS1', 'RSRC1', 'UBE2F-SCLY', 'UBE2F', 'KCNS3', 'LINC02613 - HNRNPLL', 'LINC01208 - MTND5P15', 'CHEK2P5 - KSR1P1', 'LSAMP', 'DCUN1D2', 'LINC00466', 'MTUS2', 'SEMA4D', 'DLC1 - SGCZ', 'LINC01568', 'ZFHX3', 'SLC52A1 - ZFP3-DT', 'TIAM1', 'TACC2', 'CYSLTR2 - PSME2P2', 'PRIM2BP', 'TTLL10-AS1', 'TTLL10', 'GLI3', 'BSNDP4 - RNU6-417P', 'LINC01427 - LINC00261', 'MMS22L - MIR2113', 'SLC6A1', 'SLC6A1-AS1', 'LINC01951 - ARL2BPP6', 'RPL15P15 - LINC02151', 'SGCG', 'LRRC3B - NEK10', 'JAKMIP2-AS1', 'LINC01277', 'LINC01085 - LINC00504', 'MIR4280HG - LINC01949', 'LINC02232', 'ERBB4', 'FOXN3', 'LINC01684 - LINC01692', 'SEC24D', 'ADRA2C - OR7E163P', 'DMD - FAM47A', 'MIR4719 - MON1B', 'UPF3B', 'NCLN', 'LINC01938 - RN7SKP60', 'IFI16', 'SERPINB11', 'PTPRG', 'SPOCK3 - RN7SL776P', 'PACRG', 'RPS6P15 - GPAM', 'POU2AF1', 'CICP17 - ROBO2P1', 'CCDC170', 'ADGRV1', 'RPL32P35 - TJAP1P1', 'ZNF423', 'LINC00895 - SEPTIN5', 'GPR158 - GPN3P1', 'RPS11P1 - PGAM3P', 'RNA5SP286 - RORB-AS1', 'NOVA1-DT', 'FAM153A - OR1X5P', 'CARD11', 'SNTG1', 'BCL11A - RN7SL361P', 'RPS3AP6 - NMNAT1P5', 'CMIP', 'HLA-DRB5 - RNU1-61P', 'MECOM', 'SPATA6', 'AMPD1', 'RGS21 - RGS1', 'CDCP1 - RPS24P8', 'N4BP2', 'PSORS1C1', 'EPM2A', 'TERT - MIR4457', 'CDC20B - MCIDAS', 'CCDC26', 'CLIC6']
# Genes: 220
#
# Proteins: 102
#
# Number of edges: 15
#
# P-value: 0.0365
# ovarian clear cell adenocarcinoma EFO_1000042
# Genes mapped to ovarian clear cell adenocarcinoma: ['HNF1B']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 27
#
# P-value: 7.61e-06
# ovarian endometrioid carcinoma EFO_1001515
# Genes mapped to ovarian endometrioid carcinoma: []
# Genes: 0
#
# Failed to retrieve data: 400 Client Error: Bad Request for url: https://string-db.org/api/tsv-no-header/ppi_enrichment
# Failed to retrieve PPI enrichment data.
# Error processing ovarian endometrioid carcinoma: P-value could not be extracted from response.
# hepatocyte growth factor measurement EFO_0006903
# Genes mapped to hepatocyte growth factor measurement: ['MGAT4C', 'TMEM132D', 'LDLRAP1', 'STMN1', 'SEPTIN2P1 - MATR3P3', 'CAMSAP2', 'LINC01818 - RND3', 'SERPINE2', 'RNU6ATAC28P - LINC02305', 'HTT', 'HGFAC', 'ATXN1', 'UMAD1', 'SEMA3C - EIF4EP4', 'HGF', 'HGF - CACNA2D1', 'CACNA2D1', 'CALD1', 'Y_RNA - RNF32-DT', 'BPNT2 - RNA5SP266', 'HAO1', 'PSMG1', 'BRWD1', 'GET1-SH3BGR', 'SH3BGR', 'YRDCP3 - LINC00323', 'RGS12', 'DPH1', 'NOTCH2', 'OTUD7A', 'P2RY2', 'HGFAC - DOK7', 'NR1D2 - LINC00691', 'MSANTD1 - RGS12']
# Genes: 34
#
# Proteins: 23
#
# Number of edges: 2
#
# P-value: 0.059
# lymphocyte percentage of leukocytes EFO_0007993
# Genes mapped to lymphocyte percentage of leukocytes: ['CSF3R', 'TTC39A', 'LINC01767 - PLPP3', 'LEPR', 'MIER1', 'GLMN', 'VCAM1 - EXTL2', 'PPIAP7 - LINC01307', 'OR10Z1', 'ACKR1', 'CADM3-AS1', 'LY9', 'NR1H3', 'GLULP3 - UBASH3B', 'ETS1', 'LTBR - RPL31P10', 'CD69', 'BORCS5', 'LINC02356', 'RNA5SP375 - SBNO1', 'FLT3', 'ELF1', 'LINC02341', 'KLF12', 'STXBP6', 'ZBTB25', 'RIN3', 'TRAF3', 'ITPKA', 'EHD4', 'IQGAP1', 'LRRK1 - CHSY1', 'Y_RNA - Y_RNA', 'SPECC1', 'ZNF778', 'CRK', 'ZBTB38', 'TADA2B', 'TBC1D1', 'LINC02513', 'KLF3-AS1', 'LINC02283 - LINC02260', 'CXCL8 - CXCL6', 'PPBPP2 - CXCL2', 'LIN54', 'NFKB1', 'RPL6P14 - RNU6-351P', 'TET2', 'IL7R', 'EBF1', 'MXD3', 'RIPOR2', 'HLA-A - HLA-W', 'LINC02571 - HLA-B', 'LTA', 'HLA-DQB1', 'DENND1B - C1orf53', 'MROH3P', 'COQ8A', 'MFSD2B', 'DNMT3A', 'ZFP36L2', 'IL18RAP', 'ACOXL', 'MIR4435-2HG', 'IL1RN', 'RBMS1', 'LINC01934', 'ITGA4', 'FLACC1', 'CASP8', 'CXCR2', 'CXCR2 - CXCR1', 'CMC1', 'SETD2', 'FOXP1', 'DNAJB8-AS1 - G
R', 'GLIS3', 'RCL1', 'MIR31HG', 'CDKN2A', 'CDKN2B-AS1 - DMRTA1', 'TLE4', 'RNY4P18 - MIR7702', 'TRAF1', 'GFI1B', 'ABO', 'ADAMTS13', 'SNAPC4', 'LINC02908', 'RPL32P23 - RBM17', 'GATA3', 'BEND7', 'GAD2 - APBB1IP', 'LINC02652', 'RPL9P21 - TMEM72-AS1', 'VSTM4', 'ARID5B', 'JMJD1C', 'PTEN', 'ACTA2', 'FAS', 'LIPA', 'Y_RNA - EXOC6', 'PIK3AP1', 'RPL12P27 - FRAT1', 'GBF1', 'GRK5', 'FAM53B', 'SIRT3', 'TSPAN32', 'RHOG', 'LDLRAD3', 'DDB2', 'CCDC26 - MTRF1LP2', 'RPSAP20 - LINC01767', 'PLPP3', 'LEPR - RN7SL854P', 'DNAI4', 'ADGRL4', 'RN7SL824P - GFI1', 'VCAM1', 'DPH5-DT - S1PR1-DT', 'S1PR1', 'S1PR1 - PPIAP7', 'DENND2D', 'ANP32E', 'CTSS', 'SPTA1', 'IFI16', 'PRKAG3 - RPL23AP31', 'RETREG2 - ZFAND2B', 'KCNE4', 'NYAP2 - MIR5702', 'SP140', 'SP140L', 'RNU6-451P - LINC01907', 'SYN2 - GSTM5P1', 'PLCL2', 'SATB1-AS1', 'CX3CR1', 'ACKR2', 'CYP8B1', 'CCRL2 - LINC02009', 'KIF9-AS1', 'GNAI2', 'ARHGEF3', 'WWP1P1 - ST3GAL6-AS1', 'NR1I2', 'RN7SL51P - RN7SL18P', 'LINC02934', 'ARHGAP25', 'TCF7L1 - TGOLN2', 'TBC1D8', 'RPL17P15 - PTPN4', 'HS6ST1 - Y_RNA', 'HNRNPKP2 - UBBP1', 'ARHGAP15', 'LY75-CD302', 'LY75', 'ADCY5', 'GATA2', 'MSL2', 'MBNL1', 'MBNL1-AS1', 'RN7SL300P - LINC02006', 'TNIK', 'ACAP2 - PPP1R2', 'TBC1D ...
# Genes: 510
#
# Proteins: 323
#
# Number of edges: 270
#
# P-value: 0.0
# hepatocellular carcinoma EFO_0000182
# Genes mapped to hepatocellular carcinoma: ['TRIM31', 'HLA-DPA2', 'MICD', 'TRIM26 - HCG17', 'DLC1', 'AGA-DT', 'LINC02360 - LINC02270', 'MRPS11 - DET1', 'HLA-DQB1 - MTCO3P1', 'HLA-S - MICA', 'MTCO3P1 - HLA-DQB3', 'STAT4', 'EFCAB11', 'CCR4 - GLB1', 'C2', 'HLA-DQA1', 'GRIK1', 'No mapped genes; No mapped genes; HLA-DQA1', 'KIF1B', 'VEPH1', 'PRSS23', 'IFNL3 - IFNL4', 'TM6SF2', 'SEPTIN14P17 - WNT3A', 'PNPLA3', 'MAU2', 'TERT']
# Genes: 27
#
# Proteins: 14
#
# Number of edges: 1
#
# P-value: 0.0955
# basal cell carcinoma EFO_0004193
# Genes mapped to basal cell carcinoma: ['CASP8', 'LINC02929', 'PARD6B - BCAS4', 'ST3GAL6-AS1', 'DHX35 - LINC01734', 'TSPYL5 - SNORD3H', 'COLEC10', 'CTLA4 - ICOS', 'SCAF1', 'CDYL - RPP40', 'LINC00570', 'BRCA2', 'EFEMP2', 'FRMD4A', 'RBMS1 - RN7SL423P', 'EXO1', 'SEC16A', 'ATP11A', 'HAL', 'TRPS1', 'RAET1L - RAET1M', 'PIK3R1 - VWA8P1', 'KANK1', 'RNU6-649P - LINC01248', 'TNS3', 'UBAC2', 'GPR183', 'GPX4', 'ZBTB7B', 'CCDC88B', 'SPMIP7', 'SMC2', 'PPARGC1B', 'TICAM1 - PLIN3', 'LINC02889 - SNX13', 'HAUS6', 'FGF10-AS1', 'STN1', 'CYP1B1', 'CASC15', 'HERC2', 'CTSH', 'PCSEAT - LINC00111', 'LINC00513', 'LINC-PINT', 'BNC2 - RN7SL720P', 'CDKN2B-AS1', 'JDP2', 'CLPTM1L', 'HLA-DRB1 - HLA-DQA1', 'TYR', 'RCC2', 'RHOU - LINC02815', 'KRT5', 'LINC02973 - RNU6ATAC37P', 'RALY', 'CPVL', 'MC1R', 'IRF4', 'ZFHX4-AS1', 'LINC02676 - LINC00709', 'RGS22', 'RNU6-1213P - Y_RNA', 'MYL10 - CUX1', 'RNASET2 - MIR3939', 'TGM3', 'TP53', 'FLACC1', 'SLC45A2', 'GACAT3 - CYRIA', 'FOXP1', 'LPP', 'ANKRD11', 'SLC6A17', 'RAC1', 'CTSS', 'THNSL2 - MRPL45P1', 'PTPN22', 'BACH2', 'IRF4 - EXOC2', 'RNA5SP299 - LINC02676', 'ASTN2', 'FOXP1-IT1', 'CSN3 - CABS1', 'MTCO3P1 - HLA-DQB3', 'HLA-B', 'SNHG32 - NEU1', 'STN1 - SLK', 'UBAC2 - CCR12P', 'PADI6', 'LINC03086 - TGM3', 'CHMP1A', 'SPIRE2', 'DEF8', 'FAM157C', 'MYO15A', 'SBNO2', 'STK35', 'PUDPP3 - BPIFB3', 'TRPC4AP - EDEM2', 'EPB41L1', 'RN7SL680P - HSPE1P1', 'CEP43', 'CD200', 'BNC2', 'TERT', 'CELF2-DT - ORMDL1P1', 'EXOC2', 'HCG27 - HLA-C', 'HLA-DRB6', 'HLA-DQA1', 'RHOBTB2', 'ZBTB10', 'SMC2-DT - SMC2', 'OVOL1 - CFL1', 'VDR', 'PRDX5 - CCDC88B', 'TPCN2', 'TYR - NOX4', 'LNCRNA-IUR - FAM76B', 'SUOX - IKZF4', 'LRRC43', 'FBRSL1', 'CKB', 'OCA2', 'GAS8', 'DLGAP4', 'RNASET2', 'AHR', 'CERS2 - ANXA9', 'DSTYK - TMCC2', 'RNU2-47P - TYRP1', 'SMC2 - TOPORSLP', 'INPP5E', 'IL2RA', 'LINC02674 - RAB11FIP2', 'SOX6', 'FADS2', 'FOXO6 - RNA5SP45', 'PHTF1 - RSBN1', 'DCST1', 'LINC00886', 'MIR4457 - CLPTM1L', 'ADAMTS12 - RXFP3', 'ADGRV1', 'ST3GAL6', 'P4HA2', 'CLEC16A - HNRNPCP4', 'TRIB1AL - LINC02964', 'SLA2', 'PVT1', 'INPP5B', 'PIGU', 'MICA - LINC01149', 'ANKLE1 - ABHD8', 'PTPN14', 'TEX41', 'GRHL1', 'ITPR2-AS1', 'SSPN', 'RAI1', 'ZNF276', 'FANCA', 'URAHP', 'PEBP4', 'LINC01320', 'RPL37A-DT', 'CNTN5', 'LINC01331', 'LINC01734 - ATG3P1', 'C11orf65', 'LRRC34', 'RBM6', 'ZAN', 'SMAD3', 'RAB5B', 'QRSL1P1 - XCL2', 'HLA-DRB9', 'LINC03062 - MIR4290HG', 'FAM172BP - TRMT10C', 'INCENP', 'LINC02649', 'RNU6ATAC37P - LINC01871', 'PTCSC2', 'PIWIL4-AS1', 'AMOTL1', 'GABBR1', 'G3BP1', 'STRN', 'RBM12 - NFS1', 'OSMR-DT', 'RCC2 - ARHGEF10L', 'RNU6-41P - LAMC1', 'GPR137B', 'FAM227B', 'LINC02929 - ALDH7A1P4', 'RNU4-64P - TLR3', 'PLCL1', 'SNTA1 - CBFA2T2', 'ATP8B4', 'CALCRL-AS1', 'TFPI', 'ZNF469 - ZFPM1', 'LINC02571 - HLA-B', 'HLA-DPA1', 'CENPW - MIR588', 'FGF10-AS1 - LINC02224', 'MROH8', 'TUBB3', 'MTAP - CDKN2A-DT', 'CPNE7', 'CASP8 - TRAK2', 'KRT6A - KRT5', 'JAZF1', 'DLX2-DT - ITGA6', 'AFG3L1P', 'GAPDHP77 - GUCY2F', 'LINC02676', 'LINC01488 - CCND1', 'C2CD6', 'DUSP22 - IRF4', 'HLA-DRA - HLA-DRB9', 'TCF25', 'BPIFB6 - PUDPP3', 'CD109', 'PPIL3', 'RPS27P25 - COX6A1', 'HLA-DQB1-AS1', 'HLA-DQB1', 'JARID2', 'RPS2P1 - ASIP']
# Genes: 231
#
# Proteins: 121
#
# Number of edges: 45
#
# P-value: 2.39e-11
# family history of lung cancer EFO_0006953
# Genes mapped to family history of lung cancer: ['BRCA2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 45
#
# P-value: 3.38e-13
# keratinocyte carcinoma EFO_0010176
# Genes mapped to keratinocyte carcinoma: ['SLC6A17', 'EPB41L1', 'TYR', 'RCC2', 'FLACC1', 'CASP8', 'RGS22', 'GACAT3 - CYRIA', 'ANKRD11', 'GOLPH3L', 'STRN', 'RNU6-1213P - Y_RNA', 'TNS3', 'JDP2', 'COLEC10', 'BNC2', 'ATP11A', 'SMC2', 'CELF2-DT - ORMDL1P1', 'HAL', 'BRCA2', 'ST3GAL6-AS1', 'HLA-DOA - HLA-DPA1', 'TSPYL5 - SNORD3H', 'LINC02929', 'TGM3', 'CEP43 - CCR6', 'LINC02889 - SNX13', 'OVOL1 - CFL1', 'UBAC2 - CCR12P', 'CYP1B1', 'TERT', 'CASC15', 'RAET1L - RAET1M', 'PIK3R1 - VWA8P1', 'TRPS1', 'DHX35 - LINC01734', 'LINC00570', 'STN1', 'CTSH', 'TP53', 'RALY', 'CPVL', 'LINC02973 - RNU6ATAC37P', 'LINC02676 - LINC00709', 'LINC03086 - TGM3', 'HLA-DRB1 - HLA-DQA1', 'MYL10 - CUX1', 'LINC00513', 'LINC-PINT', 'HERC2', 'PHTF1 - RSBN1', 'CDKN2B-AS1', 'BACH2', 'KRT5', 'CLPTM1L', 'HLA-S - MICA', 'EXO1', 'RHOU - LINC02815', 'THNSL2 - MRPL45P1', 'MC1R', 'DEF8', 'ZFHX4-AS1', 'IRF4', 'SLC45A2', 'FGF10-AS1', 'KANK1', 'HAUS6', 'RNU6-649P - LINC01248', 'FOXP1', 'RAC1', 'MICA - LINC01149', 'SPMIP7', 'LPP', 'CCDC88B', 'PCSEAT - LINC00111', 'ZNF276', 'FANCA', 'PARD6B - BCAS4', 'ZBTB7B', 'CTLA4', 'PPARGC1B', 'CDYL - RPP40', 'LINC02571 - HLA-B', 'GPX4 - SBNO2', 'TICAM1 - PLIN3']
# Genes: 86
#
# Proteins: 47
#
# Number of edges: 18
#
# P-value: 2.38e-06
# cutaneous melanoma EFO_0000389
# Genes mapped to cutaneous melanoma: ['MYNN', 'SYNE2', 'TP53', 'BACH2', 'MTAP - CDKN2A-DT', 'PPARGC1B', 'RNA5SP293 - RPS15AP27', 'PARP1 - RPS3AP7', 'MC1R', 'LINC01488 - CCND1', 'PLA2G6', 'CYP1B1', 'ATM', 'FMN1', 'TYR', 'MTAP', 'STN1 - SLK', 'CDKN2B-AS1', 'CDKN2A', 'LINC00466', 'CLPTM1L', 'AKAP12', 'MX2', 'ADD3', 'TASOR2', 'DCST2', 'TERT', 'FHIP2B', 'PLXNB2', 'CDH1', 'CDCA7L - RAPGEF5', 'GPR37', 'GPRC5A', 'RPL7P40 - PSMC1P8', 'MSC-AS1', 'RNU2-47P - TYRP1', 'DTNB', 'LINC-PINT', 'ATP11A', 'POU2F3 - TLCD5', 'LINC01622 - FOXQ1', 'RAPGEF1', 'AHR', 'SOX6', 'TERT - MIR4457', 'KIAA0930', 'MPHOSPH6-DT - RN7SKP190', 'HAL', 'ADGRV1', 'CASP8', 'CERS2', 'RNU6-921P - ZFP36L1', 'FTO', 'MITF', 'SLC45A2', 'SPATA33 - CDK10', 'DSTYK - TMCC2', 'MFSD12', 'TEKTIP1', 'CASC15 - RPL6P18', 'LINC01505', 'RTEL1', 'RTEL1-TNFRSF6B', 'HLA-DQB2 - HLA-DOB', 'CDKN2B', 'RALY', 'OCA2', 'NIPAL3', 'HERC2', 'ZNG1A - DOCK8-AS1', 'MED13L', 'CDKAL1', 'RMDN2', 'RMDN2-AS1', 'STN1', 'WDPCP', 'RNU6-637P - TERC', 'TPCN2 - SMIM38', 'GPRC5A - GPRC5D-AS1', 'MHENCR - STMN3', 'SAMMSON', 'LINC02674 - RAB11FIP2', 'TYR - NOX4', 'C11orf65', 'CORO7-PAM16', 'CORO7', 'MPHOSPH6', 'ANKRD11', 'RPS2P1 - ASIP', 'DCLRE1B', 'RPS27AP6 - CTXND2', 'DSTYK', 'ADAMTS12 - RXFP3', 'OSMR-DT', 'TYRP1', 'BNC2 - RN7SL720P']
# Genes: 96
#
# Proteins: 57
#
# Number of edges: 44
#
# P-value: 0.0
# Uveal Melanoma EFO_1000616
# Genes mapped to Uveal Melanoma: ['FABP1 - THNSL2', 'KCNJ3', 'BRINP1 - LINC01613', 'PRELID3A', 'ARL6IP6 - UBQLN4P2', 'STAP1', 'CACNA2D1', 'LRP1B', 'MOGAT1', 'LSM3 - LINC01267', 'FTH1P21 - LINC02272', 'RN7SL554P - RREB1', 'GFRA1', 'DEPDC4', 'ACTR6', 'TDP1', 'GNB5', 'RPL12P40 - RN7SKP182', 'LINC01991 - LPP-AS2', 'LINC02622 - UNC5B', 'AP2B1', 'RFX3-DT', 'DYNAP - RAB27B', 'CLPTM1L', 'OCA2', 'HERC2', 'IRF4', 'RN7SKP93 - MGAT5', 'LINC01957 - TRIM36', 'ADAMTSL1', 'CORO2A', 'RPS3AP5 - LINC01519', 'LINC02744 - TRIM29', 'RPP40P2 - RNU7-88P', 'DSEL-AS1', 'RNU6-266P - DDX53']
# Genes: 36
#
# Proteins: 18
#
# Number of edges: 2
#
# P-value: 0.0179
# malignant epithelial tumor of ovary MONDO_0018364
# Genes mapped to malignant epithelial tumor of ovary: ['LMCD1-AS1', 'UGT2B4 - UGT2A2', 'TENM2-AS1 - WWC1', 'AKR1C3', 'UGT2A1', 'UGT2A2', 'BNC2 - RN7SL720P', 'LINC00824', 'HAGLR', 'HAGLROS', 'TIPARP', 'BABAM1', 'USHBP1', 'SKAP1', 'CHMP4C', 'MLLT10', 'HNF1B', 'TERT', 'NSF', 'WNT4', 'RSPO1', 'SYNPO2', 'MAGI2', 'RPL12P36 - Metazoa_SRP', 'Y_RNA - MKNK2P1', 'SRGAP1', 'ABO - Y_RNA', 'COL15A1', 'ZBTB18 - RN7SL148P', 'RAD23BP2 - SEMA3A']
# Genes: 30
#
# Proteins: 18
#
# Number of edges: 2
#
# P-value: 0.0207
# non-melanoma skin carcinoma EFO_0009260
# Genes mapped to non-melanoma skin carcinoma: ['ZSWIM6 - C5orf64', 'RGS22', 'CASP8 - TRAK2', 'ZFHX4', 'CDKN2B-AS1', 'LINC01515', 'LINC01377 - LINC01019', 'KRT5', 'ZNF341', 'BZW1', 'FOXP1', 'CDH15 - SLC22A31', 'CPVL', 'DEFB136 - DEFB135', 'FDFT1', 'RHOU - LINC02815', 'EPB41', 'ZNF276', 'ZNF480', 'HLA-DQB1 - MTCO3P1', 'BNC2 - RN7SL720P', 'DNAH2', 'BNC2', 'CSMD2', 'IRF4', 'GRM5', 'GACAT3 - CYRIA', 'SNTA1 - CBFA2T2', 'ZFHX4-AS1', 'MYH7B', 'TYR', 'RNU6-682P - SNORA70', 'PRDX5 - CCDC88B', 'TRPC4AP - EDEM2', 'SCAND1', 'CNBD2', 'DNMT3B', 'PIGU', 'RPL18P1 - ATP5MC2P2', 'PARD6B - BCAS4', 'RALY', 'PHF20', 'LINC03086 - TGM3', 'GABRG3', 'TPM3P2 - PIGPP3', 'UQCC1', 'NCOA6', 'MARK2P11 - LINC02227', 'Y_RNA - Y_RNA', 'THNSL2 - MRPL45P1', 'BACH2', 'AFG3L1P', 'EXOC2', 'ANKRD11', 'RCC2', 'EPB41L1', 'CASC
# Genes: 200
#
# Proteins: 112
#
# Number of edges: 29
#
# P-value: 1.08e-05
# cutaneous squamous cell carcinoma EFO_1001927
# Genes mapped to cutaneous squamous cell carcinoma: ['CTXND2', 'RN7SL602P - SMIM7P1', 'CASP8', 'FLACC1', 'FOXP1', 'TPRG1 - TP63', 'SLC45A2', 'IRF4', 'HLA-DQA1', 'BACH2', 'AHR', 'TRPS1', 'RNU2-47P - TYRP1', 'BNC2 - RN7SL720P', 'SEC16A', 'ZNF143 - WEE1', 'TYR', 'RPL15P15 - LINC02151', 'KRT6A - KRT5', 'HAL', 'OCA2', 'MC1R', 'RALY', 'BRCA2', 'DUSP22 - IRF4', 'BNC2', 'LPP', 'CPVL', 'RPL17P30 - AP3M2', 'LINC02929', 'CTLA4 - ICOS', 'INPP5E', 'BPIFB6 - PUDPP3', 'CTSS', 'TRPC4AP - EDEM2', 'MICA - LINC01149', 'MROH8', 'BPIFB6', 'EPB41L1']
# Genes: 39
#
# Proteins: 25
#
# Number of edges: 9
#
# P-value: 2.14e-09
# estrogen-receptor positive breast cancer EFO_1000649
# Genes mapped to estrogen-receptor positive breast cancer: ['FGFR2', 'CASC16', 'DIRC3-AS1', 'AMPD2 - RPL7P8', 'IRF1', 'IRF1-AS1', 'SCAMP2', 'LINC01101 - Y_RNA', 'ARHGEF38', 'SLC25A21', 'TTC39C']
# Genes: 11
#
# Proteins: 6
#
# Number of edges: 0
#
# P-value: 1.0
# progesterone-receptor negative breast cancer EFO_0009781
# Genes mapped to progesterone-receptor negative breast cancer: ['FGFR2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 16
#
# P-value: 0.0762
# Ewing sarcoma EFO_0000174
# Genes mapped to Ewing sarcoma: ['RNA5SP63 - U3', 'LINC03083 - LINC00237', 'XRN2', 'C1orf127 - CFL1P6', 'SRP14-DT', 'EGR2 - RNU6-543P', 'BTF3P7 - RN7SL554P', 'LINC01727', 'RPL24P2', 'ZYXP1 - FAM135B']
# Genes: 10
#
# Proteins: 1
#
# Number of edges: 19
#
# P-value: 0.0077
# small cell lung carcinoma EFO_0000702
# Genes mapped to small cell lung carcinoma: ['HMGN4 - ABT1', 'ZNF322 - GUSBP2', 'CREB5', 'RPL3P8 - IMMP2L', 'HAUS6P1 - RNF138P2', 'GNGT1', 'SMIM30 - PPP1R3A', 'SPMIP7 - IKZF1', 'LHFPL3', 'DPP6 - PAXIP1-AS2', 'BSNDP4 - RNU6-417P', 'COL21A1', 'BMP6', 'SCIN', 'SKAP2', 'UMAD1', 'FAM167A', 'FAM167A-AS1', 'DLC1', 'ADAMTSL1', 'IL33', 'NRP1 - LINC02628', 'UBASH3B - CRTAM', 'STK33', 'DISC1FP1', 'PIWIL4', 'PIWIL4-AS1', 'EPHB1 - SDHBP1', 'BBX', 'TMA16', 'MARCHF1 - RNU6-284P', 'NDUFB5P1 - LINC00290', 'FSTL4 - WSPAR', 'FCHO2', 'ADGRV1', 'NEDD9', 'BTN3A1', 'RAD52', 'A2ML1 - PHC1', 'LINC02822', 'BRCA2', 'LINC00383', 'TMEM179 - LINC02280', 'RGS6', 'FOXN3', 'ALDH1A2', 'CHRNA5', 'CHRNB4', 'GOLGA6GP', 'LINC02254', 'ADAD2', 'UBE2G1 - SPNS3', 'VSTM1 - TARM1', 'DYNC2H1 - MIR4693', 'IL17RC', 'LINC01556 - KRT18P1']
# Genes: 56
#
# Proteins: 29
#
# Number of edges: 2
#
# P-value: 0.1401
# testicular carcinoma EFO_0005088
# Genes mapped to testicular carcinoma: ['KITLG', 'SLC25A44', 'LINC00690 - DAZL', 'CENPE', 'PITX1', 'HEATR3 - RPL10P14', 'SEPTIN4-AS1', 'TERT - MIR4457', 'NDFIP1 - SPRY4', 'DMRT1', 'ATF7IP', 'UCK2', 'PRDM14', 'MCM3AP', 'GGNBP1', 'BAK1', 'TERT', 'CENPE - LINC02428', 'RFWD3', 'HPGDS', 'LIPG', 'MAD1L1', 'NELL1', 'CLDN14 - SIM2', 'DEPDC1-AS1 - LINC01707', 'RN7SL117P - RNA5SP87', 'Y_RNA - CRIP1P3', 'ACTL8', 'MIR4457 - CLPTM1L', 'EZRP1 - ALCAM', 'PRTG', 'ZNF675', 'C12orf50']
# Genes: 33
#
# Proteins: 20
#
# Number of edges: 2
#
# P-value: 0.0352
# male breast carcinoma EFO_0006861
# Genes mapped to male breast carcinoma: ['PRKACB', 'RAD51B', 'CASC16', 'CCDC170', 'CCDC170 - ESR1', 'ESR1', 'MLLT10', 'LINC01488 - CCND1']
# Genes: 8
#
# Proteins: 5
#
# Number of edges: 2
#
# P-value: 0.0193
# central nervous system cancer EFO_0000326
# Genes mapped to central nervous system cancer: ['RTEL1-TNFRSF6B', 'RTEL1', 'CDKN2B-AS1', 'TERT', 'CCDC26', 'PHLDB1', 'EGFR', 'SEC61G-DT - EGFR', 'GOLGA3', 'ZBTB16', 'SNORA70 - RN7SL734P', 'ETFA', 'POLR2A', 'HPSE2', 'POLR3B', 'TP53', 'LRRC31', 'LINC00424 - LINC00540', 'LRRC4C', 'ATP8A1-DT - RN7SKP82', 'COPS8-DT', 'PIEZO2 - LINC01928', 'PAPPA2', 'C12orf42-AS1 - C12orf42', 'KLF7']
# Genes: 25
#
# Proteins: 15
#
# Number of edges: 6
#
# P-value: 0.0702
# chronic myelogenous leukemia EFO_0000339
# Genes mapped to chronic myelogenous leukemia: ['CCDC170', 'TUFMP1 - RPL34P31']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 5
#
# P-value: 0.3726
# esophageal squamous cell carcinoma EFO_0005922
# Genes mapped to esophageal squamous cell carcinoma: ['STING1', 'ATP1B2', 'HLA-DRB1 - HLA-DQA1', 'CDKN2B-AS1', 'HHLA1', 'PLCE1', 'CASP8', 'FLACC1', 'RUNX1', 'XBP1', 'PDE4D', 'RALBP1P2 - NMS', 'C1D', 'HIGD1AP4 - SCG2', 'SLC30A4-AS1', 'LINC02987 - MAN1A2P1', 'SLC16A14', 'SLC16A14 - SP110', 'Y_RNA - FAM120AOS', 'CHEK2', 'MYO1B', 'PCM1', 'AGBL4', 'GSE1', 'CCDC71L - LINC02577', 'MUC7 - AMTN', 'ABHD11 - CLDN3', 'RBBP8', 'TNFRSF10C - TNFRSF10D', 'STAT4', 'FANCC', 'MIR99AHG', 'LINC02127', 'TWSG1', 'UBXN2B - CYP7A1', 'CDCA2 - EBF2', 'TSEN2P1 - ADAM20P2', 'SERINC5', 'PRKG1', 'LINC02141', 'CHRM3-AS2', 'CHRM3', 'LINC01429 - RNU6-347P', 'UBE3D']
# Genes: 44
#
# Proteins: 24
#
# Number of edges: 3
#
# P-value: 0.1155
# endothelial growth factor measurement EFO_0006900
# Genes mapped to endothelial growth factor measurement: ['EGF']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 48
#
# P-value: 2.67e-13
# lung cancer MONDO_0008903
# Genes mapped to lung cancer: ['PSMA4 - CHRNA5', 'CLPTM1L', 'CYP2A6', 'SUMO2P1 - MOG', 'BRCA2', 'SECISBP2L - COPS2', 'AK5', 'CHRNA4', 'WNK1', 'CHRNA2', 'RN7SL151P - MTAP', 'MPZL2', 'RNASET2 - MIR3939', 'CHEK2', 'QRSL1P1 - XCL2', 'ADI1P3 - STBD1P1', 'TP53BP1', 'RNU6-699P - RNU1-63P', 'JADE2', 'LSAMP - RNU6-1200P', 'LINC01470', 'EPHX2 - GULOP', 'TERT - MIR4457', 'SECISBP2L', 'MIR3939 - CEP43', 'MMS22L', 'TERT', 'LINC01149 - HCP5', 'CHRNA5', 'LINC00943', 'LINC00944', 'PKDCC - EML4-AS1', 'LINC02056', 'ZRANB1', 'EIF4A3P1 - LINC01915', 'IRX2-DT - LINC01377', 'RPSAP37 - LINC02039', 'MAP7', 'CSMD1', 'AMD1P1 - MIR4675', 'ATP8B1', 'GRIK1', 'BACH1', 'TENM2-AS1', 'TENM2']
# Genes: 45
#
# Proteins: 22
#
# Number of edges: 7
#
# P-value: 2.97e-06
# clear cell renal carcinoma EFO_0000349
# Genes mapped to clear cell renal carcinoma: ['TERT - MIR4457', 'DNAJC16', 'LENEP - ZBTB7B', 'PMF1', 'PMF1-BGLAP', 'PIGR - FCAMR', 'MAD1L1', 'GRB10', 'CDK6', 'MYO7B', 'TNFRSF10B', 'TEX41', 'TEX41 - RPL6P5', 'LRP2', 'FANCD2', 'ZNF438 - LINC02664', 'ENTPD3-AS1', 'SFMBT1', 'RNU6-488P - PROS1', 'ACTRT3 - MYNN', 'LINC02068', 'NR1H3', 'INCENP', 'MYEOV', 'MYEOV - LINC02956', 'LINC02956 - LINC02953', 'LINC02953 - LINC02952', 'LINC02952 - LINC02747', 'LINC01488 - CCND1', 'NPAT', 'C11orf65', 'EXPH5', 'ITPR2-AS1', 'SSPN', 'SCARB1', 'DPF3', 'DPF3 - DCAF4', 'ADSS1', 'AKT1', 'TLN2', 'TIPIN', 'CNEP1R1', 'AP3D1', 'INSR', 'MHENCR - STMN3', 'HSCB', 'EMID1', 'LINC01342 - MIR200B', 'GMDS', 'CDKAL1 - LINC00581', 'DINOL', 'CDKN1A', 'LINC02580', 'EPAS1', 'IRF5', 'PVT1', 'PALM2AKAP2', 'MLLT10', 'ZNF438', 'VHL', 'DDIT4 - DNAJB12', 'STN1 - SLK', 'KCNQ1', 'KCNQ1OT1', 'H2AZ1-DT', 'RCC2P8 - COL25A1', 'TERT', 'GRAMD4', 'REPS2', 'MTND4P24 - DCAF12L1']
# Genes: 70
#
# Proteins: 41
#
# Number of edges: 6
#
# P-value: 0.1172
# renal carcinoma EFO_0002890
# Genes mapped to renal carcinoma: ['SCARB1', 'DPF3', 'ZFYVE1', 'PSEN1', 'NUMB', 'AKT1', 'TLN2', 'TIPIN', 'LCTL', 'CNEP1R1', 'DLG4', 'TP53', 'AP3D1', 'INSR', 'RBBP8NL - GATA5', 'MHENCR - STMN3', 'STMN3', 'RTEL1', 'RTEL1-TNFRSF6B', 'ZBTB46', 'TTC28', 'EMID1', 'GCAT', 'NCAPH2', 'REPS2', 'MTND4P24 - DCAF12L1', 'DNAJC16', 'CDKN2C - MIR4421', 'PMF1-BGLAP', 'PMF1', 'PIGR - FCAMR', 'EXO1', 'LINC02580', 'Metazoa_SRP - EPAS1', 'EPAS1', 'MYO7B', 'TMEM163', 'ZEB2', 'TEX41', 'TEX41 - RPL6P5', 'LRP2', 'FANCD2', 'VHL', 'KAT2B', 'ENTPD3-AS1', 'FBXW12', 'SFMBT1', 'RNU6-488P - PROS1', 'NSUN3 - ARMC10P1', 'TFDP2', 'ACTRT3 - MYNN', 'LINC02068', 'PPARGC1A', 'H2AZ1-DT', 'RCC2P8 - COL25A1', 'SLC6A19', 'TERT', 'TERT - MIR4457', 'GMDS', 'CDKAL1 - LINC00581', 'DINOL', 'CDKN1A', 'MTHFD1L', 'MAD1L1', 'GRB10', 'POT1', 'IRF5', 'TNFRSF10B', 'RBPMS', 'PVT1', 'MLLT10', 'ZNF438 - LINC02664', 'STN1 - SLK', 'KCNQ1', 'INCENP', 'MYEOV', 'MYEOV - LINC02956', 'LINC02956 - LINC02953', 'LINC02953 - LINC02952', 'LINC02952 - LINC02747', 'LINC01488 - CCND1', 'ATM', 'C11orf65', 'SLC6A13', 'ITPR2-AS1', 'SSPN', 'ITPR2', 'NTN4']
# Genes: 88
#
# Proteins: 59
#
# Number of edges: 37
#
# P-value: 6.25e-08
# bile duct cancer MONDO_0003059
# Genes mapped to bile duct cancer: ['TRAPPC9']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 55
#
# P-value: 0.0
# angiopoietin-2 measurement EFO_0006901
# Genes mapped to angiopoietin-2 measurement: ['MCPH1']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.00045
# breast cancer MONDO_0007254
# Genes mapped to breast cancer: ['HTRA1', 'MTUS2', 'TOX3', 'IGSF5', 'ZNRF3', 'CCDC170 - ESR1', 'DLGAP2', 'PSD3', 'CCDC171', 'CD9', 'CDH8', 'PIRAT1 - RMDN2', 'PPP2R2B', 'CCNJP1 - RNU6-1335P', 'ECE1-AS1', 'ECE1', 'CCL21 - SPATA31F1', 'ADARB2', 'LYZL6 - CCL16', 'CEP131', 'KCNJ6', 'TNRC6B', 'LINC02854 - LINC01445', 'ZNF649 - ZNF613', 'ARHGAP32', 'RAD51B', 'ERBB4 - LINC01878', 'CTTNBP

# Genes: 1
#
# Proteins: 1
#
# Number of edges: 9
#
# P-value: 0.3028
# urinary bladder cancer MONDO_0001187
# Genes mapped to urinary bladder cancer: ['GLDN']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 9
#
# P-value: 0.0187
# prostate cancer MONDO_0008315
# ...
# Genes: 340
#
# Proteins: 150
#
# Number of edges: 37
#
# P-value: 9.28e-05
# colorectal cancer MONDO_0005575
# Genes mapped to colorectal cancer: ['SMAD7', 'TBX3-AS1 - UBA52P7', 'SCG5 - GREM1-AS1', 'LINC00536 - EIF3H', 'POU2AF3', 'COLCA1', 'RPS27P4 - MRPS31P1', 'LRIG1', 'NOS1', 'NKX2-3 - SLC25A28', 'SH2B3', 'ATXN2', 'DCBLD1', 'PREX1', 'POU5F1B', 'PCAT1', 'CCAT2', 'CASC8', 'POLD3', 'CCND2', 'LINC02331 - MIR5580', 'TARDBPP1 - CASC20', 'GPATCH1', 'SYMPK', 'LINC01082 - LINC01081', 'GOLGA8B', 'TCF7L2', 'FADS2', 'RNA5SP299 - LINC02676', 'CASC20 - LINC01713', 'MYRF', 'TMEM258', 'CABLES2', 'LINC02474 - LINC01705', 'ZMIZ1-AS1', 'PLCH1', 'LINC02917 - MBNL1', 'PLA2G10FP - SPRING1P3', 'VTI1A', 'CCND2-AS1', 'PITX1-AS1', 'LINC01728 - TOX2', 'LINC01228 - DYNLRB2-AS1', 'AADACL2-AS1 - LINC02917', 'SLCO2A1', 'CALB1 - LINC00534', 'MACF1', 'UBQLN4P2 - ATP5PBP4', 'PCNX1', 'MMP2', 'CRTC3', 'LINC01709', 'PDZD2', 'CACNA2D1', 'CHRM3 - RPS7P5', 'FAM83B', 'PDCD2L - UBA2', 'TRPC6', 'ATP6V1G1P7 - RPL7P45', 'KAZN', 'RNU6-185P - LINC00052', 'NDUFA5P5 - ICE2P2', 'CAPN9 - RNA5SP79', 'SMIM14', 'TCF4', 'RBAKDN - OR10AH1P', 'PTPRN2', 'HERC2', 'C2orf92 - ZAP70', 'RNU1-76P - LINC02226', 'HLA-F', 'LINC02641', 'CFAP44', 'CFAP44-AS1', 'KCNIP4', 'WWOX', 'SLC25A21', 'RPL36AP49 - ZNF519', 'DOCK3', 'PVT1', 'GARRE1', 'RN7SKP279 - DNAJB6P1', 'TMTC1 - LINC02386', 'FAM107A', 'HS3ST4 - LINC02195', 'TMEM212-AS1', 'LINC02699 - ANO3', 'UBE2D3P4 - MTND4P1', 'OR1J2', 'DELEC1', 'SMAD9', 'DRG1', 'EIF4ENIF1', 'KRT18P8 - RAB31', 'RASGEF1B', 'CBLN2', 'LINC01173', 'OSBP2', 'RPL7AP69 - USP29', 'PIWIL4-AS1', 'PIWIL4', 'CLMP - U8', 'RBFOX1', 'FENDRR', 'AKR1B1P6 - RAB12', 'PUM1', 'GNG12', 'HNRNPKP2 - UBBP1', 'RAP1BP2 - EZRP1', 'FAM193A', 'LUCAT1', 'Metazoa_SRP - ADTRP', 'KIAA0319', 'BTBD9', 'ADGRB3', 'PRKN', 'CP
L1 - LINC02188', 'LINC02257', 'UTP23', 'DIP2B', 'BMP4', 'GREM1-AS1', 'LINC02474', 'CNTN5 - RN7SL222P', 'ACAD10', 'CDKN2B-AS1', 'EIF3H', 'LINC02356', 'LINC01081 - LINC00917', 'LINC00511', 'METRNL - RPL23AP87', 'DLGAP1', 'FUT6 - FUT3', 'KLF2-DT', 'MAMSTR', 'SLC27A5', 'BMP2 - LINC01428', 'PIGU', 'TOX2', 'LINC01271 - RN7SL636P', 'RIPOR3', 'RTEL1', 'RTEL1-TNFRSF6B', 'PCNT', 'ZNRF3-IT1', 'ZNRF3', 'PDGFB - RPL3' ...
# Genes: 675
#
# Proteins: 334
#
# Number of edges: 134
#
# P-value: 3.61e-14
# acute myeloid leukemia EFO_0000222
# Genes mapped to acute myeloid leukemia: ['LINC02314 - DIO3OS; LINC02314 - DIO3OS; LINC02314 - DIO3OS', 'LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A; LINC02250 - ATP10A', 'GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2; GABRG3 - OCA2', 'CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7; CHRNA7', 'LINC02895; LINC02895; LINC02895; LINC02895; LINC02895; LINC02895', 'SLC24A5; LINC01491 - SLC24A5; SLC24A5; LINC01491 - SLC24A5; LINC01491 - SLC24A5; LINC01491 - SLC24A5; LINC01491 - SLC24A5; LINC01491 - SLC24A5; SLC24A5; MYEF2', 'DTWD1 - ATP8B4; DTWD1 - ATP8B4; DTWD1 - ATP8B4; DTWD1 - ATP8B4', 'LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490; LINC02490', 'LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1; LIPC; ALDH1A2; LIPC-AS1', 'GOLGA2P11 - MIR8067; GOLGA2P11', 'UACA; UACA; UACA; UACA; UACA; UACA; UACA; UACA; UACA; UACA; UACA', 'TMEM266; TMEM266', 'SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER - RCN2; SCAPER; SCAPER; SCAPER; SCAPER; SCAPER; SCAP
# Genes: 1080
#
# Proteins: 136
#
# Number of edges: 21
#
# P-value: 0.0266
# lymphocyte count EFO_0004587
# Genes mapped to lymphocyte count: ['LINC01767 - PLPP3', 'RERE', 'SLC35D1', 'DPH5-DT - S1PR1-DT', 'S1PR1-DT - S1PR1', 'S1PR1', 'PPIAP7 - LINC01307', 'PTPN22', 'SPTA1', 'LY9', 'ATP6V1G3 - PTPRC', 'PTPRC', 'ATP2B4', 'IKBKE', 'IKBKE-AS1', 'MFSD2B', 'DNMT3A', 'GCKR', 'TNIK', 'PAK2', 'TBC1D1', 'TBC1D1 - LINC02513', 'LINC02513', 'KLF3', 'ANTXR2', 'SCD5', 'MANBA', 'TET2', 'SPEF2 - IL7R', 'SLC12A2-DT', 'IRF1', 'IRF1-AS1', 'MACROH2A1', 'BTF3P7 - RN7SL554P', 'RREB1', 'RIPOR2', 'HLA-G - HCP5B', 'POU5F1', 'LINC02571 - HLA-B', 'HCP5', 'ZFP36L2', 'PLEK', 'IL18RAP - SLC9A4', 'ACOXL', 'MIR4435-2HG', 'PAX8', 'PAX8-AS1', 'ARHGAP15', 'RBMS1', 'LINC01934', 'CASP8', 'NYAP2 - MIR5702', 'PTMA - PDE6D', 'SYN2 - GSTM5P1', 'SATB1-AS1', 'EOMES - LINC01980', 'CMC1', 'CX3CR1', 'SETD2', 'ARHGEF3', 'FOXP1', 'ADCY5', 'ZBTB38', 'PDYN-AS1', 'PLCB1', 'DNMT3B', 'COX6CP2 - PTPN1', 'ZNF831', 'LINC02920 - CYCSP42', 'DIP2A', 'ARVCF', 'UBE2L3', 'TTC28', 'XBP1 - ZNRF3', 'HORMAD2 - LIF-AS1', 'CBX7', 'ARRDC2', 'SMG9 - KCNN4', 'SAE1', 'SIGLEC5', 'RAP1GAP2', 'ARRB2 - MED11', 'MINK1', 'TNFRSF13B', 'RAI1', 'SLC47A1', 'SSH2', 'IKZF3', 'CCR7', 'CCR7 - SMARCE1', 'CD300LF', 'RAB37', 'SPHK1', 'UBE2O', 'BCL2', 'ARHGAP45', 'ARHGEF18', 'LIMASI', 'ICAM1', 'ICAM3 - TYK2', 'MIR23AHG', 'KLF2 - EPS15L1', 'EPS15L1', 'LTA', 'TSBP1', 'TSBP1-AS1', 'HLA-DRB9 - HLA-DRB5', 'PPARD', 'BACH2', 'SCML4', 'RNU1-18P - HSF2', 'L3MBTL3', 'HBS1L - MYB', 'DAGLB - RPL31P34', 'ETV1', 'STEAP1B', 'JAZF1', 'RN7SL496P - CDK13-DT', 'MYO1G', 'TRPC6P3 - GIMAP6', 'PINX1', 'ANK1', 'IL7', 'RNF19A - MIR4471', 'PVT1', 'CYRIB', 'CDKN2A', 'CDKN2B-AS1 - DMRTA1', 'CD69 - GCNAP1', 'BORCS5', 'CDKN1B - APOLD1', 'HDAC7', 'SPIC', 'SH2B3', 'ATXN2', 'KMT5A - RILPL2', 'DNAH10', 'ELF1', 'KLF12', 'SWINGN - C13orf46', 'CFAP97D2', 'PPP2R3C', 'FAM177A1', 'NFKBIA', 'ZBTB25', 'MTHFD1', 'JDP2 - BATF', 'TRAF3 - AMN', 'IQGAP1', 'ADCY9', 'CLEC16A', 'Y_RNA - Y_RNA', 'NLRC5', 'MEAK7', 'ANKRD11', 'TLE4', 'MIR4289 - PCNPP2', 'TRAF1', 'FUT7', 'LINC02908', 'LINC02908 - NPDC1', 'IL2RA', 'PRTFDC1', 'GAD2 - APBB1IP', 'MARCHF8', 'VSTM4', 'SUPV3L1 - HKDC1', 'CDH23', 'VSIR', 'AGBL2', 'CNTN5 - RN7SL222P', 'EXPH5', 'ABCG4', 'GLULP3 - UBASH3B', 'ETS1', 'ETS1 - FLI1', 'NINJ2', 'TNFRSF1A', 'LTBR - RPL31P10', 'CD69', 'KALRN', 'GATA2', 'PLXND1', 'STAG1-DT - SULT1D1P2', 'CHST2 - PBX2P1', 'PLSCR4', 'MBNL1', 'RN7SL300P - LINC02006', 'IL12A-AS1', 'MCCC1', 'ABCC5 - EEF1A1P8', 'IGF2BP2 - TRA2B', 'LINC01991 - LPP-AS2', 'ACAP2 - PPP1R2', 'KIAA0232 - TBC1D14', 'RHOH - LINC02265', 'GSX2 - RPL22P13', 'NMU', 'SPINK2 - REST', 'GC', 'GPRIN3', 'RN7SL89P - PPA2', 'EGF', 'FAM241A', 'BBS12 - FGF2', 'NR3C2', 'RNA5SP169 - LINC02273', 'GUCY1A1', 'PDGFC', 'DDX60L', 'RETREG1-AS1', 'IL7R', 'PELO-AS1', 'AK4P2 - SLC38A9', 'PGAM1P1 - PLK2', 'LINC02219 - PIK3R1', 'TMEM171', 'IQGAP2', 'ST8SIA4', 'CAMK4', 'TAF8', 'CDC5L - SUPT3H', 'ELOVL5', 'ATG5', 'BEND3 - RNU6-1299P', 'CD164 - PPIL6', 'FCF1P10 - SOCS5P5', 'HSF2', 'RSPO3', 'HBS1L', 'CCDC170', 'MYCT1', 'TAGAP-AS1', 'LINC01624', 'COX19', 'ADAP1', 'CARD11 - SDK1-AS1', 'ACTB', 'MIR148A - NFE2L3', 'TNFAIP8', 'LINC02240', 'P4HA2', 'PDLIM4', 'SH3TC2', 'ANXA6', 'TIMD4 - HAVCR1', 'LINC02227 - EBF1', 'LINC01845 - LINC01847', 'LINC01944 - NEURL1B', 'NKX2-5 - Y_RNA', 'LINC01485', 'NSD1', 'SQSTM1', 'IRF4', 'GCNT2', 'ADTRP', 'RN7SKP204', 'RNU6-793P - RPL6P17', 'JARID2', 'MBOAT1 - E2F3', 'CASC15', 'RNU6-1060P - SPTLC1P2', 'HOXA3', 'HOXA-AS3', 'HOXA6', 'SEPTIN7P3 - MARK2P13', 'ELMO1', 'CDK13', 'DDC', 'EGFR', 'NIPSNAP2', 'AUTS2', 'STAG3L2', 'GCNT1P5 - PTPN12', 'SEMA3D', 'CDK6-AS1', 'BAIAP2L1', 'ARPC1A', 'FIS1', 'CBLL1', 'CBLL1-AS1', 'CAV1', 'ZNF800', 'UBE2H', 'LINC-PINT', 'BPGM - TUBB3P2', 'ZC3HAV1', 'GIMAP4 - TRPC6P3', 'LMBR1', 'PPP1R3B-DT', 'FDFT1', 'PSD3', 'DOK2', 'KCTD9', 'RBPMS', 'RBPMS-AS1', 'TCIM - SIRLNT', 'PLAG1', 'LINC01301', 'NCOA2', 'MSC-AS1', 'NBN', 'RN7SL563P - GRHL2', 'ZFPM2', 'SAMD12-AS1', 'TRIB1AL', 'DENND3 - SLC45A4', 'KRT18P39 - NPM1P33', 'CPS1', 'PRKAG3 - RPL23AP31', 'KCNE4', 'DOCK10', 'RNU6-451P - LINC01907', 'EIF4E2', 'SAG', 'THRB',  ...
# Genes: 1170
#
# Proteins: 667
#
# Number of edges: 928
#
# P-value: 0.0

# %%
noncancers = get_pvalue(noncancers)
# Out:
# atopic eczema EFO_0000274
# Genes mapped to atopic eczema: ['LCE1F - LCE1E', 'CRCT1 - LCE3E', 'FLG-AS1 - LCE5A', 'RN7SL335P - BLTP1', 'SMARCA4', 'CIART - MRPS21', 'LINC00299', 'PUS10', 'CD207 - LINC01143', 'IL7R - CAPSL', 'RPL13AP18 - RNU6-1213P', 'IL15RA - IL2RA', 'LINC02098 - ETS1', 'PPP2R3C', 'FAM177A1', 'STAT3', 'IL1R1', 'KIF3A', 'CLEC16A', 'IL2 - IL21', 'EMSY - LINC02757', 'IL18R1', 'AP5B1 - OVOL1', 'NFILZ', 'RTEL1-TNFRSF6B', 'RTEL1', 'IL6R', 'OVOL1', 'TH2LCRR', 'IL18R1 - SDR42E1P5', 'HLA-DRB1 - HLA-DQA1', 'LINC02929', 'DPY19L2P2', 'PRR5L', 'LCE3A - LCEP4', 'SLC9A4', 'IL13', 'TNFRSF6B', 'ZNF652-AS1', 'LINC02571 - HLA-B', 'LINC02757', 'KRT8P26 - AP5B1', 'PBX2 - GPSM3', 'TSBP1-AS1', 'TSBP1', 'OR10A3 - NLRP10', 'MIR4435-2HG', 'GLB1', 'CCDC80 - MAT2AP1', 'CARD11 - SDK1-AS1', 'LINC00824', 'ALDH7A1P4 - ADO', 'CYP24A1 - PFDN4', 'NCF4', 'NCF4-AS1', 'ATP6V1G2-DDX39B', 'DDX39B', 'FLG-AS1', 'TNXB', 'MFN2', 'GRM4', 'RN7SL474P - FGF20', 'AUTS2 - GALNT17', 'XIRP2-AS1', 'XIRP2', 'CDKN2B-AS1 - DMRTA1', 'RNF111', 'STAT3 - CAVIN1', 'S100A11', 'NLRP10', 'ZBTB38', 'TLR1', 'BLTP1', 'IL7R', 'SLC25A46 - BCLAF1P1', 'WDR36 - RPS3AP21', 'ITGB8 - EEF1A1P27', 'EHMT1', 'IL2RA', 'KRT8P37 - CHCHD3P1', 'LINC02676 - LINC00709', 'LAYN - SIK2', 'ERBB3', 'STAT6', 'TRAF3', 'SMAD3', 'IQGAP1', 'AFF1', 'ITGB8', 'EGR2', 'PUDPP
DLEU7', 'WDR11 - RPL19P16', 'CPO - KLF7', 'CNTLN', 'CTNND2', 'ANK1', 'RORA', 'PSD3', 'DSTNP5 - PARD3B', 'PCDH10 - PABPC4L', 'NRXN3 - DIO2', 'CERKL', 'ETV6', 'C3orf49', 'MYBPC1', 'ARHGEF38', 'RNU6-225P - SCARF2', 'COX7A2L - KCNG3', 'KCNG3', 'SLC9A4 - SLC9A2', 'MME', 'GUSBP5', 'RNU6-381P - FGF10', 'FGF10-AS1 - LINC02224', 'HLA-D ...
# Genes: 646
#
# Proteins: 370
#
# Number of edges: 153
#
# P-value: 4.82e-08
# allergic rhinitis EFO_0005854
# Genes mapped to allergic rhinitis: ['RN7SL474P - FGF20', 'LINC02240', 'LINC02920 - CYCSP42', 'HMGB3P18 - RNU1-18P', 'FERD3L - POLR1F', 'LINC01426', 'PRDM16', 'BSND', 'LINC00486', 'DLG1-AS1 - LINC02012', 'SYCP2L', 'FAM157D - LINC03015', 'NKAIN3', 'RN7SKP120 - TUSC1', 'RNU6-1228P - OTX2P1', 'ABCA1', 'LINC00705 - AKR1E2', 'THAP12P4 - LINC02726', 'RN7SKP297 - CHRDL2', 'DYRK4', 'ST8SIA2', 'RBFOX1', 'FTO', 'CDRT8 - PMP22', 'LAMA3', 'ZNF671 - ZNF776', 'RBX1 - Y_RNA', 'HLA-DQA1 - HLA-DQB1', 'IL18R1', 'IL1RL1', 'TLR1', 'WDR36 - RPS3AP21', 'EMSY - LINC02757', 'HLA-B', 'CLEC16A - HNRNPCP4', 'ZPBP2', 'IL2 - IL21', 'LINC00299', 'RANBP6 - GTF3AP1', 'PLCL1', 'LPP', 'LINC02676 - LINC00709', 'SMAD3', 'RPL13AP18 - RNU6-1213P', 'SULT1A1', 'RAD50', 'TTC6', 'PVT1', 'NFATC2', 'IL7R', 'CDK2AP1', 'BACH2', 'COX7CP3 - SETP16', 'FCER1G', 'RTF1', 'NFKB1', 'JAZF1', 'ATXN2', 'ABO', 'DCAF1', 'FOSL2-AS1', 'MFSD13A', 'ACTR1A', 'NEGR1 - RPL31P12', 'SLC7A10 - CEBPA', 'SPPL3', 'DAW1', 'RORA', 'RERE', 'LINC02341', 'AQP5-AS1', 'AQP2', 'SIK3', 'MIER1', 'SLC25A46 - BCLAF1P1', 'CCR7 - SMARCE1', 'ALOX15', 'D2HGDH', 'SPEF2 - IL7R', 'CLEC16A', 'MIR3142HG', 'EYA2', 'MTND4LP25 - CBLN1', 'CD247', 'BCL6 - LINC01991', 'RPS26 - ERBB3', 'ZNF217', 'IQGAP1', 'ADAD1', 'GTF3AP1 - IL33', 'ITGB8', 'POLR1HASP', 'NEPRO-AS1 - BOC', 'TSLP - WDR36', 'DLC1']
# Genes: 95
#
# Proteins: 50
#
# Number of edges: 8
#
# P-value: 0.0142
# obstructive sleep apnea EFO_0003918
# Genes mapped to obstructive sleep apnea: ['NRG1', 'LINC01619', 'PACRG-AS1', 'PACRG', 'SLC52A3', 'RPS10-NUDT3 - PACSIN1', 'JCAD', 'ATP6V1C1', 'EEF1A1P11 - RN7SL831P', 'TYW3 - LHX8', 'GFI1', 'PPIEL', 'LINC01122', 'THADA', 'CAMKMT - LINC01833', 'LINC01876', 'R3HDM1', 'TMEM163', 'LINC01822 - RN7SL117P', 'ETV5', 'DGKG', 'CADM2', 'SLC39A8', 'PRDX4P1 - THAP12P9', 'PCSK1 - CAST', 'MMS22L - MIR2113', 'GAPVD1', 'ECM2', 'CENPP', 'CNNM2', 'NRP1', 'TCF7L2', 'HSD17B6', 'PRIM1', 'CCDC77', 'ZNF646P1 - LINC00558', 'NRXN3', 'SCAPER', 'FTO', 'NSF', 'APOE', 'LINC01524', 'TBX15 - WARS2', 'RPL21P71 - ZIC4', 'SNTG1', 'GAPVD1 - Metazoa_SRP', 'METTL15', 'MSRB3', 'DLEU1', 'DLEU7', 'LINC02409 - RMST', 'CAMK1D']
# Genes: 52
#
# Proteins: 32
#
# Number of edges: 2
#
# P-value: 0.136
# chronic kidney disease EFO_0003884
# Genes mapped to chronic kidney disease: ['UMOD - PDILT', 'SLC13A3', 'PPIAP66 - RPL5P7', 'PSD4 - PAX8-AS1', 'RGS14', 'BCAS3', 'L3MBTL3', 'LINC02750 - OR4C50P', 'RNF32-DT', 'SLC47A1', 'OR4B2P - OR4X2', 'SLC39A13-AS1', 'SPI1', 'PIP5K1B', 'CEP89', 'DIRC3-AS1', 'LINC02694', 'MYPN', 'EPB41L3', 'SPTBN1', 'GUSBP18 - RAI14-DT', 'TFCP2L1', 'RGS19', 'ZNF436-AS1 - TCEA3', 'STC1 - RNU1-148P', 'ARG1', 'RERG', 'MYO19', 'LINC02920 - CYCSP42', 'PDILT', 'HOXD-AS2', 'LARP4B', 'WDR72', 'NFATC1', 'PPM1J - PPM1J-DT', 'ALMS1P1', 'CPS1', 'TRIM49B', 'DAB2', 'KRT8P26 - AP5B1', 'UNCX - MICALL2', 'SLC34A1', 'SHROOM3', 'PRDM8 - FGF5', 'SDCCAG8', 'GATM', 'AQP4-AS1', 'MPPED2-AS1 - DCDC1', 'SLC22A2', 'PRKAG2', 'HOXD1 - RPSAP25', 'AGL - SLC35A3', 'RN7SL571P - KCTD12', 'GIPC2 - RNFT1P2', 'LINC00624', 'RN7SL553P - MTARC2P1', 'LINC02264 - NDST3', 'THSD7A', 'LYPLA2P3 - FOXB2', 'RNU6-783P - LINC02686', 'ZAR1L', 'LINC02284', 'FTO', 'LINC02140 - LINC02183', 'CDRT15 - HS3ST3B1', 'LINC-ROR - BOD1L2', 'C22orf31 - KREMEN1', 'APOL1', 'YBX1P9 - PARP1', 'RPN1', 'AKAP8P1 - JKAMPP1', 'NMT2 - FAM171A1', 'CDON', 'C12orf75', 'DPPA3P11 - UBE2FP2', 'LINC02188', 'LUC7L3', 'DSCAM', 'PCSEAT - LINC00111', 'COL6A5', 'MARCHF1', 'ANP32CP', 'MUC17', 'MOB3C', 'MKNK1', 'PLCB2', 'CXCL8', 'VPS33B', 'TMOD4', 'ADGRL3', 'ZNF77', 'COL6A3', 'DLGAP2', 'RNLS', 'MBNL1 - ATP5MGP5', 'RPL23AP22 - EEF1A1P14', 'KBTBD11-OT1', 'ARHGEF10', 'ECM2', 'CENPP', 'DPF3 - DCAF4', 'LINC01804', 'PVT1', 'UMOD', 'MRPS30 - HCN1', 'SALL4P5 - RPL24P7', 'ARHGEF28P1 - COL8A1', 'SOX11 - LINC01810', 'RN7SKP27 - LINC02923', 'DHX35 - LINC01734', 'HNRNPA1P67 - RNU4ATAC9P', 'COPS5P1 - EPHA7', 'CPSF2', 'EIF4A1P1 - RPL10P1', 'ESRRG - GPATCH2', 'STEAP1B', 'GPX1P2 - EIF4A1P1', 'RPL35AP19 - HAS2', 'GCNT1', 'SLC24A4 - RIN3', 'TET3', 'PDZRN3', 'CALM2', 'GAS2', 'HORMAD2 - LIF-AS1', 'PTPRM', 'ABCA4', 'PCSK2', 'SVIP', 'NRG1', 'SH3BP4', 'LINC02789', 'EEF1A1P44', 'APOL4 - APOL2', 'RRM2 - RN7SL66P', 'RNU6-627P - FIGN', 'MADD', 'LINC02049 - STXBP5L', 'IDI2', 'GTPBP4', 'AFG2B', 'HTR3B', 'RNA5SP404 - GRIN2A', 'RB1', 'PLCB1', 'ADCY5 - HACD2', 'CCSER1', 'CELF2-DT - ORMDL1P1', 'NPHP4', 'ATXN7L1', 'LHPP', 'TSHR - GTF2A1', 'RNU7-88P - DIAPH3', 'INSYN1-AS1 - TBC1D21', 'DPEP1', 'GCKR', 'INHBC', 'KCNQ1', 'LPP', 'SLC25A26', 'LRIG1', 'LRP2', 'NFAT5', 'RREB1', 'SFMBT1', 'SIPA1L3', 'SLC2A9', 'LINC00113 - LINC00314', 'HIGD1AP4 - SCG2', 'LINC01320']
# Genes: 170
#
# Proteins: 92
#
# Number of edges: 15
#
# P-value: 0.0011
# chronic hepatitis B virus infection EFO_0004239
# Genes mapped to chronic hepatitis B virus infection: ['HLA-DQB3 - HLA-DQA2', 'HLA-DQB2', 'HLA-DPB1', 'HLA-DPA3', 'HLA-DQB2; HLA-DQB2; HLA-DPA3; HLA-DQB3 - HLA-DQA2; HLA-DPB1', 'HLA-DQB1 - MTCO3P1', 'HLA-DPA1', 'CFB', 'NOTCH4', 'HLA-DOA', 'CD40', 'HCG27 - HLA-C', 'EHMT2-AS1', 'EHMT2', 'TCF19', 'RN7SL563P - GRHL2', 'RBMX2P4 - ETV1']
# Genes: 17
#
# Proteins: 9
#
# Number of edges: 5
#
# P-value: 3.69e-07
# autism spectrum disorder EFO_0003756
# Genes mapped to autism spectrum disorder: ['INHCAP', 'CUEDC2', 'LINC00399 - LINC00676', 'RP1L1 - SOX7', 'RN7SKP32 - RNU6-819P', 'ASAP1 - ADCY8', 'C8orf90 - MIR1302-7', 'RSU1', 'EGR2 - RNU6-543P', 'MRPL35P2 - RPL7AP50', 'GUCY1A2', 'PCDH9', 'ESRRB', 'SERPINA2 - SERPINA1', 'LINC02210-CRHR1', 'MAPT', 'L3MBTL4', 'GALNT1', 'NEDD4L', 'ZNF568', 'MACROD2', 'KIZ', 'ZNF877P - XRN2', 'EEF1A1P11 - RN7SL831P', 'LINC01776 - SNX7', 'FTLP17 - CDK4P1', 'LINC01031 - RPL23AP22', 'PKP4', 'SGO1-AS1', 'CADPS', 'RSRC1', 'RN7SKP222 - FGF12', 'LINC00461', 'LINC02058', 'NIHCOLE - RNU6-334P', 'KCNN2', 'GALNT10', 'ADTRP', 'RNU6-1060P - SPTLC1P2', 'SPTLC1P2 - HNRNPA1P58', 'GABBR1', 'MIR2113 - EIF4EBP2P3', 'KMT2E', 'EXT1', 'PTPRN2', 'MAD1L1', 'SMIM21', 'FGFR1', 'SSUH2', 'NLRP4', 'POLR2E', 'SORBS1', 'LUZP2', 'CHST1 - MIR7154', 'LINC00376', 'HS6ST3 - HSP90AB6P', 'LINC00922', 'CCDC102B - DOK6', 'MPPED1', 'PTOV1P1 - LRRC58', 'PBX2P1 - SLC9A9', 'ZNF354A - AACSP1', 'RNU6-682P - SNORA70', 'LINC02823 - LINC02404', 'NPY - RNU6-1103P', 'SORCS3', 'RBFOX1', 'DCC', 'NAALADL2', 'LINC01151', 'OR2M4', 'SGSM2', 'LINC00907', 'NEGR1', 'ITIH3', 'GPR89P - RSL24D1P1', 'RNU7-160P - BAG5', 'TMF1P1 - ERCC4', 'KIZ - ZNF877P', 'LPO', 'HSF5', 'TLK1', 'FTH1P21 - LINC02272', 'GALNT12', 'THSD4', 'CITED1', 'DCAF12L2 - MTCO1P53', 'ARHGEF6 - RPL7P56', 'OR5V1', 'OR12D2', 'RAET1E', 'RAET1E-AS1', 'PKIA-AS1', 'LINC01498', 'MGAT5B', 'PFAS', 'HLA-B', 'RNF144A', 'QPCT - RNU6-1116P', 'SFTA2', 'SLC8A3', 'ANXA9', 'LINC02196 - Metazoa_SRP', 'CTR9', 'HLA-DMA', 'MICA', 'Y_RNA - RPS27P11', 'MTHFD1L', 'DOCK8', 'H2AZ2', 'CCDC88C', 'ITGA11', 'ZKSCAN8', 'MYO9B', 'ZNF600', 'RPL23AP39 - RPL21P17', 'CD55', 'HIGD1AP18 - PKIA-AS1', 'TMEM185B - RALB', 'TMEM38A - NWD1']
# Genes: 120
#
# Proteins: 68
#
# Number of edges: 4
#
# P-value: 0.216
# autism EFO_0003758
# Genes mapped to autism: ['LINC00399 - LINC00676', 'SNHG18 - TAS2R1', 'PDE8B', 'ZBED3-AS1', 'RNU6-374P - MSNP1', 'PARD3B', 'RNU6-164P - ARL2BPP5', 'EYA1 - U8', 'TAF1C', 'MACROD2', 'PPP2R5C', 'MSNP1 - RNU4-43P', 'CSDE1; AMPD1 - RN7SL432P', 'CSDE1; AMPD1 - RN7SL432P; CSDE1', 'TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33', 'TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33', 'TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33', 'TRIM33; TRIM33 - PKMP1; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33; TRIM33', 'PKMP1; PKMP1 - BCAS2; TRIM33 - PKMP1', 'PKMP1; PKMP1 - BCAS2', 'TRIM33', 'AMPD1 - RN7SL432P', 'Y_RNA - LINC02409', 'AMELY', 'TBL1Y', 'DDX3Y', 'UTY', 'KDM5D', 'EIF1AY', 'SLC52A2; FBXL6; ADCK5', 'MYO9B; MYO9B', 'NFIA-AS2', 'NFIA', 'ESRRG', 'SYNPR', 'SYNPR-AS1', 'TENM2', 'RN7SKP159 - MCPH1-DT', 'BSX - SAE1P1', 'PAFAH1B2P2 - MIR4495', 'RN7SL571P - KCTD12', 'NAB1P1 - Metazoa_SRP']
# Genes: 42
#
# Proteins: 17
#
# Number of edges: 10
#
# P-value: 5.7e-14
# hepatitis B virus infection EFO_0004197
# Genes mapped to hepatitis B virus infection: ['HLA-DQB2', 'HCG27 - HLA-C', 'UBE2L3', 'HLA-DPB1', 'HLA-DPA1', 'EHMT2-AS1', 'EHMT2', 'TCF19', 'GRIN2A', 'HLA-DQB1 - MTCO3P1', 'HLA-DRB1 - HLA-DQA1', 'HLA-DPA2 - COL11A2P1', 'AFG1L']
# Genes: 13
#
# Proteins: 8
#
# Number of edges: 2
#
# P-value: 0.0029
# ulcerative colitis EFO_0000729
# Genes mapped to ulcerative colitis: ['DSE - CBX3P9', 'RPL5P26 - COL13A1', 'LINC01958 - RPLP0P7', 'LINC02380 - SRIP1', 'ACTR3B - LINC01287', 'CPXM2', 'MYT1L - LINC01250', 'INAVA', 'MST1', 'PTPRC', 'NOTCH4 - TSBP1-AS1', 'CFB', 'MICB-DT', 'HLA-DQB1', 'HLA-DQB1-AS1', 'CCL20', 'CAMK2A', 'LNC-LBCS', 'ABI1 - FAM238C', 'TOM1', 'HLA-DQA1', 'RNF186-AS1 - OTUD3', 'IL23R', 'LINC02940 - RPL23AP12', 'LINC01620', 'IFNG-AS1', 'IL12B - LINC01845', 'Y_RNA - IL10', 'PUS10', 'GOT1-DT - LINC01475', 'PIGCP2 - DLD', 'HNRNPA1P41 - JAK2', 'FCGR2A', 'GPR35 - AQP12B', 'RTEL1-TNFRSF6B', 'TNFRSF6B', 'GRB7 - IKZF3', 'CARD9', 'LINC02929 - ALDH7A1P4', 'PPIAP34 - ZBTB40', 'LINC03004', 'EMSY - LINC02757', 'FGFR1OP2P1 - RPS21P8', 'LINC02920 - CYCSP42', 'NR5A2', 'ADCY7', 'GATD3', 'RORC', 'GNA12', 'AMZ1', 'STAT3', 'TNFRSF14 - PRXL2B', 'IL17REL', 'LINC02132 - LINC01082', 'PDGFB - RPL3', 'KCP - IRF5', 'SLC39A11', 'TRAF3IP2-AS1', 'NXPE1', 'PARK7', 'SLC7A10 - CEBPA', 'SMAD3', 'PITX1-AS1', 'ZFP90', 'RGS14', 'PLCG2', 'RNU6-222P - FCAR', 'LSP1', 'MIR4456 - CEP72-DT', 'PRKCB', 'RNU1-150P - TTC33', 'RNU6-793P - RPL6P17', 'SMURF1 - KPNA7', 'MAML2', 'CTH - CHORDC1P5', 'Y_RNA - Y_RNA', 'EEF
ERGIC1', 'SLC2A13 - LINC02555', 'EPHB4', 'ERAP2', 'ZNF831', 'CDKAL1', 'PRDM16', 'IFFO2 - UBR4', 'COG2', 'LINC01953', 'POLR1HASP', 'NCR3 - UQCRHP1', 'BZW2', 'RNU6-144P - ZYXP1', 'LINC02625', 'LRRTM3', 'CTNNA3', 'DAPK2', 'TNRC18', 'SLIT1', 'LRRC3C - GSDMA', 'HLA-DRB6 - HLA-DRB1', 'TRIM15', 'TAP2 - PSMB8', 'IL27 - NUPR1', 'SMG1P5', 'ZFP90 - CDH3', 'TMEM170A', 'WWOX', 'CDYL2 - ARLNC1', 'CCL2 - CCL7', 'IKZF3', 'CCR7 - SMARCE1', 'SKAP1', 'PVALEF - CEP131', 'ELAC1', 'SBNO2', 'COQ8B', 'NOL4L', 'ZHX3', 'UBE2L3 - YDJC', 'LINC01399 - RNU7-167P', 'Y_RNA - RNU6-320P', 'TGFBR3', 'CASC15', 'JAK2', 'LCOR', 'IL4R - IL21R', 'MIEN1 - GRB7', 'CUL1', 'TRPS1', 'IPPK - RPL21P86', 'SNAPC4', 'IL2RA', 'PRKCQ-AS1', 'CCND3P1 - MAP3K8', 'RNU6-794P - CCNY', 'IPMK', 'ZMIZ1', 'MIR4679-2 - CH25H', 'EIF2S2P3', 'BTRC', 'ARHGAP26-AS1', 'ARHGAP26', 'RGS14 - SLC34A1', 'PHYKPL', 'CDKAL1 - LINC00581', 'TRAF3IP2', 'BTF3L4P3 - LINC03004', 'RNASET2 - MIR3939', 'LINC02889 ...
# Genes: 341
#
# Proteins: 182
#
# Number of edges: 149
#
# P-value: 0.0
# restless legs syndrome EFO_0004270
# Genes mapped to restless legs syndrome: ['PTPRD', 'LINC01677 - MTATP6P14', 'LINC01304 - NPM1P48', 'MEIS1', 'LINC01812 - FBXL12P1', 'CCDC148', 'CRBN - SUMF1', 'RN7SKP212 - GSTO3P', 'LINC02520', 'BTBD9', 'EEF1A1P28 - COX6A1P7', 'RPS10P21 - RPL18AP17', 'DPH6-DT - LINC02853', 'RN7SKP101 - SEMA6D', 'MAP2K5', 'CASC16', 'LINC02086', 'LINC01478', 'MYT1', 'RPL35P8 - MIR3667HG', 'HELLPAR', 'UTRN', 'OR8I1P - OR8K3', 'LINC02378', 'LGR6', 'RNA5SP127 - H3P11', 'SLC40A1 - ASNSD1', 'RANBP17', 'UNCX - MICALL2', 'LMO1 - STK33', 'PLEKHB2P1 - NFE2L3P1', 'LINC02339 - RAC1P8', 'KLF12 - LINC00402', 'OR5AU1', 'LINC02306', 'ACTN1', 'KCNK13', 'BCL11B - SETD3', 'PPP2R5C', 'CDIN1', 'SQOR - MTND5P40', 'LINC01491', 'UNC13C', 'RNU6-745P - LINC02205', 'SLCO3A1', 'TOX3', 'ZFHX3', 'NFE2L1-DT', 'CA10 - LINC01982', 'ASPSCR1', 'EXD3', 'LINC02669 - KLF6', 'FRMD4A', 'MLLT10', 'LINC02622 - UNC5B', 'LRMDA', 'BTRC', 'EBF3', 'LINC02667 - MGMT', 'MGM
B41L4B', 'GRID1', 'CNNM2', 'NT5C2', 'LINC01122', 'FIGN', 'SCHLAP1', 'GBE1 - LINC02008', 'TAL1', 'AUTS2', 'RPL10AP3 - LINC01288', 'LINC01414', 'YWHAZ', 'STRBP - CRB2', 'SHTN1', 'NUCB2 - NCR3LG1', 'KCNJ11', 'NCAM1', 'SOX5', 'ATXN2-AS - BRAP', 'TRAFD1 - HECTD4', 'TPCN1', 'FLT3', 'KLC1', 'KLC1-AS1', 'ABHD17C - CEMIP', 'LINC02852 - LETR1', 'CYB5B - NFAT5', 'MAP2K3 - KCNJ12', 'GGNBP2', 'MYL4 - ITGB3', 'SKAP1', 'DCAF7', 'CALM2P1 - CASC17', 'RIT2 - SYT4', 'C19orf12 - CCNE1', 'ZNF536', 'MACROD2', 'CCT5P2 - NIPA2P5', 'LINC00907', 'ETS2-AS1', 'CFAP74', 'PANK4', 'COL16A1', 'MAST2', 'SEMA6C', 'COP1', 'BRINP3', 'PANTR1', 'RAB3GAP1', 'MCM6', 'ZDBF2 - ACER2P1', 'CPS1 - RPS27P10', 'NUP210', 'CACNA1D', 'MAST4', 'RPL6P4 - C2orf50', 'Y_RNA - Y_RNA', 'LINC02214 - RPL35AP15', 'CEP162', 'KCNC1', 'SEMA4D', 'PAUPAR - LINC03031', 'COL4A4', 'LINC02915 - THBS1', 'SPRING1P3 - TCERG1P2', 'UCHL5', 'RNU6-983P - LINC01724', 'ZBTB41', 'IPO9', 'SSBP3', 'DAB1', 'LEPR', 'PDE4B', 'ARL8A', 'OPTC - ATP2B4', 'LINC01774 - TFDP1P1', 'LINC01696 - LINC01698', 'SYT14', 'LYPLAL1-AS1 - ZC3H11B', 'DNAH14', 'SDCCAG8', 'AKT3', 'ALKAL2 - LINC01865', 'LINC01865 - LINC01874', 'SNTG2', 'LINC01248', 'SILC1 - LINC01247', 'MIR3681HG - TRIB2', 'DTNB', 'PPM1G - NRBP1', 'BABAM2', 'PPP1CB', 'RN7SL602P - SMIM7P1', 'RPL21P36 - CRIM1 ...
# Genes: 3832
#
# Proteins: 1971
#
# Number of edges: 3630
#
# P-value: 0.0
# asthma MONDO_0004979
# Genes mapped to asthma: ['GSDMB', 'ADAMTS9', 'IL1RL1', 'IL18R1', 'ZPBP2', 'HLA-DQA1', 'GTF3AP1 - IL33', 'BCLAF1P1 - TSLP', 'FAM183DP - IL1RL1', 'SMAD3', 'EMSY - LINC02757', 'HLA-B', 'RAD50', 'D2HGDH', 'CLEC16A', 'ADAMTS4', 'LINC02676 - LINC00709', 'RPL13AP18 - RNU6-1213P', 'RORA', 'TLR1', 'BACH2', 'STAT6', 'LPP', 'ADORA1', 'LINC00299', 'CD247', 'RAD51B', 'CDHR3', 'NDFIP1', 'GOT2P2 - TNFSF4', 'PEX14', 'RANBP6 - GTF3AP1', 'HLA-DQA1 - HLA-DQB1', 'HLA-DRB9', 'IL2RA', 'IL4R', 'IL33', 'TH2LCRR - IL4', 'TPD52L3 - UHRF2', 'HLA-DOA - HLA-DPA1', 'PSMD3 - C
# Genes mapped to eosinophilic esophagitis: ['LINC01767 - PLPP3', 'DCC', 'LINC02785 - SLC25A24', 'CAPN14', 'TSLP', 'LINC02214 - RPL35AP15', 'XKR6', 'MIR4675 - NEBL', 'EMSY - LINC02757', 'CCDC81', 'LINC03034 - KLF13', 'HSF2BP', 'IFFO2', 'KIF17', 'CAPN5', 'CEP295NL', 'TIMP2', 'P2RX6 - SLC7A4', 'LINC02240', 'SNHG32 - NEU1', 'JAZF1', 'CLEC16A', 'BCLAF1P1 - TSLP', 'TMEM38BP1 - LINC01208', 'ATP6AP1L - RPL5P16', 'CALM2P1 - CASC17', 'SHROOM3', 'STAT6', 'LNCRNA-IUR - FAM76B', 'ERICH5', 'DSG1', 'MARK2P15 - LINC02650', 'MEAK7', 'GAPDHP15 - RBBP4P4', 'SNTB1', 'TSLP - WDR36', 'EMSY', 'ANKRD27', 'NOVA1-DT', 'PRKD3', 'TMEM182', 'CPNE4', 'WDR36 - RPS3AP21', 'URGCP-MRPS24', 'URGCP', 'RAD50', 'BOLA2P3', 'MATN2', 'PRKG1', 'RHOG - STIM1-AS1', 'SHANK2', 'WASF3 - GPR12', 'RORA', 'SMAD3', 'INO80C - GALNT1', 'LARP1BP2 - CCDC71L', 'JAK2', 'CCNY', 'BACH1', 'TOGARAM2', 'SPAG17', 'PCSK2', 'MIR4719 - MON1B', 'CASC15', 'TBC1D13', 'ADGRL3', 'RHOU - LINC02815', 'RNA5SP382 - KLHL33', 'LINC02169 - IRX3', 'SETP7 - ABTB3', 'HS3ST4', 'PSAP', 'GTPBP2', 'POLH', 'NRXN1', 'WDR25', 'IFNG-AS1', 'RNU7-155P - MYL6P5', 'HLCS', 'MTCO1P40 - RPS2P48', 'LINC02780 - EEF1DP6', 'RN7SL159P - LINC00963', 'SLC7A9', 'GRIK1', 'GRIK1-AS1', 'MIPEPP2 - CHRM3', 'RN7SL292P - SGO1P2', 'DDAH1', 'LINC01194 - LINC02220', 'MT3 - MT2A', 'LINC00598 - FOXO1', 'AEBP1', 'LINC02299', 'GPX5 - SCAND3', 'ANO3', 'FSCB - LINC02302', 'CAMK2G', 'LMCD1-AS1', 'SLC9A9', 'SLC9A9-AS1', 'RPL23AP44 - FTMT', 'ESPNL', 'FHIT', 'OTOL1 - TOMM22P6', 'LHFPL3', 'EMCN', 'SH3RF1 - NEK1', 'SCGB1D1 - SCGB2A1', 'ST6GAL1', 'PTPRD', 'GALNTL6', 'DDIT4L-AS1 - EMCN', 'RNU6-576P - LINC00701', 'STIM2', 'SUCLA2', 'SPPL2A', 'LINC00927', 'NAALADL2']
# Genes: 118
#
# Proteins: 65
#
# Number of edges: 3
#
# P-value: 0.2927
# multiple sclerosis MONDO_0005301
# Genes mapped to multiple sclerosis: ['TSBP1', 'TSBP1-AS1', 'L3MBTL3', 'DLEU1', 'MAZ', 'MVP-DT', 'TOP3A', 'ERG', 'TNFRSF14 - PRXL2B', 'GFI1', 'CD58', 'RGS1', 'Y_RNA - CD86', 'ANKRD55', 'HLA-DQA1', 'RPL32P23 - RBM17', 'ZNF438 - LINC02664', 'TNFRSF1A', 'CLEC16A', 'CD6 - LINC02954', 'OS9', 'CDHR3 - SYPL1', 'TGFBR3', 'LINC02132 - LINC01082', 'IL2RA', 'SP140', 'RNA5SP431 - MAF', 'IL20RA - IL22RA2', 'RMI2', 'SLC2A4RG', 'GTDC1', 'LINC01
 'PHACTR2', 'CEACAM16-AS1', 'MAPK10', 'BACH2', 'ATF1 - RN7SL519P', 'ETV6 - BCL2L14', 'ETV6', 'N4BP2 - RHOH', 'LINC03020 - TRAM1', 'PITPNM2', 'CLECL1P', 'NR1D1', 'BATF3 - NSL1', 'PRICKLE1', 'TBX6', 'SOX8 - SSTR5', 'GALC', 'ETS1', 'RDUR - ZPLD1', 'LNCRNA-IUR - FAM76B', 'ETV3L - ETV3', 'KCP - IRF5', 'NCOR2', 'ZNHIT3', 'IFI30 - MPV17L2', 'FAM241A', 'AHI1-DT', 'LINC01625 - ATP5PBP6', 'DRAP1 - TSGA10IP', 'CHST12', 'HTR3A', 'MERTK', 'ELMO1', 'LINC03002 - MEMO1P2', 'ARHGEF3', 'SATB1-AS1', 'IKZF3', 'MALT1', 'LEF1', 'ADI1P1 - LPIN3', 'LINC02612 - FABP5P10', 'EPPK1 - PLEC', 'SH2B3', 'ATXN2', 'CSF2RB', 'SIDT1', 'GRB2', 'LIMK2', 'THEMIS - PTPRK', 'MARCHF1', 'GIMAP6 - GIMAP2', 'LPP', 'NIHCOLE', 'EIF3EP2 - GCG', 'CAMK2G - PLAU', 'SPRED2 - LINC02934', 'PRDX5 - CCDC88B', 'TERT', 'LINC01934', 'CR1L', 'NCF4', 'NCF4-AS1', 'CRTAP', 'PLXNC1', 'ATXN1', 'PCAT1', 'CASC19', 'VANGL2', 'STAT4', 'TOX2', 'KRT18P39 - NPM1P33', 'DOCK10', 'LRRIQ4', 'SAE1', 'TRIM14', 'RHOH - LINC02265', 'ALDH1L1', 'BCL2', 'FCRL3 - VDAC1P9', 'ZNF767P', 'LINC02102 - TENT4A', 'IFNGR2', 'RNU6-921P - ZFP36L1', 'BATF - FLVCR2-AS1', 'JADE2', 'CXCR4 - HNRNPKP2', 'CBLB', 'CBFA2T3 - ACSF3', 'IL10RB - IFNAR1', 'PTPN11', 'SERBP1P3 - RFT1', 'SGSM2', 'LINC00423 - TOMM22P3', 'TMEM8B', 'FAM221B', 'LCN6', 'RORA', 'MEF2C', 'MEF2C-AS2', 'PDE4B', 'TNIP2 - SH3BP2', 'REL-DT', 'MIR4435-2HG', 'SLA', 'TG', 'LINC01353 - BTG2-DT', 'RASGEF1A', 'MINK1', 'AKAP13', 'LINC02644 - ZNF438', 'MYO5B', 'LINC00708 - KRT8P37', 'IKZF2 - LINC01953', 'NAB1', 'ENTHD1 - GRAP2', 'EXOC2', 'CASP8', 'UNK', 'SMARCA4', 'LINC01063 - NRROS', 'ANKRD36BP2', 'COG6', 'TMEM244 - L3MBTL3', 'RGCC', 'RNU6-919P - SLC9A8', 'RPS6KA5', 'ZBTB38', 'LINC02940 - RPL23AP12', 'RPL1 ...
# Genes: 468
#
# Proteins: 248
#
# Number of edges: 165
#
# P-value: 0.0
# Headache, HbA1c measurement EFO_0004541
# Genes mapped to Headache, HbA1c measurement: ['RTN4', 'FLACC1', 'CASP8', 'NBEAL1', 'TKT', 'PLXND1', 'ANAPC4', 'HSPA4', 'MLN - LINC01016', 'MAD1L1', 'UBE2V2 - IDI1P2', 'PFKM', 'CFAP97D2', 'PML - DNM1P33', 'RN7SL836P - GIPR']
# Genes: 15
#
# Proteins: 11
#
# Number of edges: 3
#
# P-value: 0.0047
# systemic lupus erythematosus MONDO_0007915
# Genes mapped to systemic lupus erythematosus: ['DGUOK-AS1', 'CD80', 'ARID5B', 'CREBL2', 'GPR19', 'CDKN1B', 'DRAM1', 'RGL1', 'APOBEC4', 'SCN10A', 'BACH2 - MIR4464', 'SLC29A3', 'SEZ6L2', 'ABHD8', 'BANK1', 'FAM167A - BLK', 'SPMIP7 - IKZF1', 'KCP - IRF5', 'STAT4', 'PDHX - CD44-DT', 'HLA-DRB1 - HLA-DQA1', 'ATG5', 'TNFAIP3', 'TNFSF4 - PRDX6-AS1', 'WDFY4', 'LINC02098 - ETS1', 'SLC15A4', 'ELF1', 'RASGRP3', 'TNIP1', 'UBE2L3', 'BLTP3A', 'CLEC16A', 'ITGAM', 'NT5C2', 'CERCAM', 'CDK18 - RNU2-19P', 'IRAK1', 'JAZF1', 'KDM4C', 'LINC01088', 'NCF2', 'SMG7', 'HSD3BP5 - ZNF697', 'LINC02520 - MIR4462', 'MAN1A1 - MIR3144', 'PPP1R3B-DT', 'MIR124-1HG - MSRA-DT', 'LINC00208 - GATA4', 'GLDC - RN7SL123P', 'LINC02834 - GAS1', 'PCNX3 - SIPA1', 'PRPS2', 'RABGAP1L', 'SLC12A1', 'SLC22A11 - SLC22A12', 'TNPO3', 'FAM171A1 - ITGA8', 'PGPEP1 - GDF15', 'PTPN22', 'TNXB', 'FAP - IFIH1', 'IKZF2', 'PDHB - KCTD6', 'IL12A-AS1', 'VDAC1 - TCF7', 'IRF7', 'ETS1 - FLI1', 'LBH', 'ATXN1', 'AP5B1', 'ATP6V1G3 - PTPRC', 'SRGAP2 - IKBKE', 'H3P5 - LBH', 'LPP', 'BACH2', 'GTF2IRD1', 'JAK2', 'ZFP90', 'BTBD8 - C1orf146', 'LINC01967', 'AHI1-DT', 'FCGR2A', 'MIR3142HG', 'SPRED2', 'IRF5', 'ATXN2', 'SCAMP5', 'IKZF3', 'TYK2', 'IRF8 - LINC02132', 'FCHSD2 - IUR1', 'AHNAK2', 'BLK', 'LINC02132 - LINC01082', 'HIP1', 'TMEM187 - IRAK1', 'ETS1', 'LYST', 'ANKS1A', 'IFIH1', 'IL10', 'NR0B1 - TASL', 'PHTF1 - RSBN1', 'RAD51B', 'GLTPD2 - PSMB6', 'RNU6-793P - RPL6P17', 'LINC00708 - KRT8P37', 'DDO', 'IL12RB2', 'AHI1', 'LCP1', 'MIR8062 - RN7SL547P', 'GRB2', 'PRSS54', 'Y_RNA - IL10', 'CFB', 'RTKN2', 'YDJC - CCDC116', 'CDHR5', 'HLA-DQA1', 'PER3P1 - U3', 'PAXBP1P1 - DPP6', 'TNFAIP3 - SIMALR', 'SLC44A4', 'IRF5 - TNPO3', 'MIR210HG', 'NADSYN1', 'PLD2', 'TASL', 'MECP2', 'KIT', 'TRMT44
B3 - HLA-DQA2', 'GABBR1 - SUMO2P1', 'MUC22', 'HCP5', 'LST1', 'SNHG32 - NEU1', 'C4B', 'HLA-DRA - HLA-DRB9', 'SYNGAP1', 'SYNGAP1-AS1', 'MIR7159 - MIR1275', 'SMIM29 - RPL35P2', 'ZNF76', 'CPNE5', 'DSE', 'IPCEF1', 'EIF4H', 'HEATR3-AS1', 'RPL23AP91 - CCL22', 'RPL35AP33 - ZFP90', 'LINC01229', 'ACAP1', 'TNFRSF13B', 'ZNF652-AS1 - PHB1', 'SOCS3-DT - PGS1', 'CD226', 'LINC03101 - CTDP1-DT', 'ARID3A', 'C3', 'SSB ...
# Genes: 634
#
# Proteins: 325
#
# Number of edges: 337
#
# P-value: 0.0
# Parkinson disease MONDO_0005180
# Genes mapped to Parkinson disease: ['GCH1', 'TMEM229B', 'RORA - LINC02349', 'BCKDK', 'MAPT', 'RIT2', 'TMPRSS9', 'LZTS3 - DDRGK1', 'MSR1 - RN7SL474P', 'HMGN2P18 - KRTCAP2', 'NUCKS1 - RAB29', 'SIPA1L2', 'CCNT2-AS1', 'STK39 - RN7SL813P', 'MCCC1', 'TMEM175', 'BST1', 'FAM47E', 'FAM47E-STBD1', 'SNCA', 'HLA-DQB1 - MTCO3P1', 'GPNMB', 'INPP5F', 'DLG2', 'SPATA19 - IGSF9B', 'LRRK2-DT', 'LRRK2', 'CCDC62', 'SLC2A13', 'LINC02210', 'LINC02210-CRHR1', 'ASS1P14 - SYT10', 'HLA-DRB1 - HLA-DQA1', 'GBA1', 'GAK', 'DCUN1D1 - MCCC1', 'HYCC1 - KLHL7-DT', 'TIAL1 - RAD1P1', 'LINC01012', 'OR5AZ1P - OR5BD1P', 'LINC02451', 'SH3GL2', 'SYT17', 'NDUFAF2', 'CA8', 'NAGLU - HSD17B1P1', 'LINC02527 - CCN6', 'LAMTOR2 - RAB25', 'CTSB', 'NUCKS1', 'ZDHHC2', 'CACNA1B', 'ITGA8', 'BAG3', 'IGSF9B', 'RESF1 - BICD1-AS1', 'MTND1P24 - LINC02400', 'GPR65', 'PFDN1P2 - CD38', 'TPM1 - LACTB', 'STX1B', 'SLC39A8', 'CAMK2D', 'ELOVL7', 'ZNF608 - LINC02240', 'RERE', 'RERE-AS1', 'KLHL7', 'MROH3P', 'ITPKB', 'LINC01127 - IL1R2', 'NGEF', 'TBC1D5', 'PARP9', 'RNA5SP144 - LARP7P4', 'MED12L', 'SPTSSB', 'GPRIN3 - SNCA', 'KANSL1', 'Y_RNA - Y_RNA', 'SMAD4 - SRSF10P1', 'MYLK2', 'DYRK1A', 'TRPM2', 'LINC02949 - LINC02950', 'SCARB2', 'VAMP4 - METTL13', 'RAB29', 'C5orf24 - TXNDC15', 'KCNIP3', 'TRIM40', 'TMEM163', 'RNU4-66P - RIMS1', 'HMGB1P13 - LINC00326', 'IP6K2', 'LINC03011 - RABGEF1P1', 'CYRIB', 'LCORL', 'PMVK', 'RNU6-481P - FCGR2A', 'CLCN3', 'PAM - EIF3KP1', 'KCNS3', '
455', 'RBX1 - Y_RNA', 'PPP6R2', 'VAMP4', 'Metazoa_SRP - NUCKS1', 'PIK3CA', 'PCGF3', 'CC2D2A', 'MMRN1', 'CCSER1', 'VN1R10P - ZNF204P', 'SLC18B1', 'PDLIM2', 'TXNP1 - INPP5F', 'MIR4485 - RNF141', 'KNTC1 - HCAR2', 'IRS2 - RN7SKP10', 'LINC01147', 'ARHGAP27', 'ASXL3 - NOL4', 'LINC02920 - CYCSP42', 'CCDC85A', 'CACNA2D3', 'MTND1P22 - GUCY1A1', 'NTRK1', 'KCNN3', 'LRRC25 - SSBP4', 'LRRC30 - PTPRM', 'GBA2', 'GNA12', 'AMZ1', 'ALK', 'TRIM46', 'PBXIP1', 'ARHGEF2', 'RIT1', 'SEMA4A', 'LMNA', 'PMF1-BGLAP', 'CCT3', 'EFNA4-EFNA3', 'GBAP1', 'DCST1', 'EFNA3 - Y_RNA', 'MUC1', 'LINC00511', 'MAD1L1', 'WDR1', 'ZNF322 - GUSBP2', 'LINC02213 - ANKRD33B', 'ASCL4 - WSCD2', 'RN7SL869P - RN7SL35P', 'MTF2', 'HMGN2P18', 'FCGR3B - FCGR2B' ...
# Genes: 325
#
# Proteins: 197
#
# Number of edges: 73
#
# P-value: 9.79e-14
# heart function measurement EFO_0004311
# Genes mapped to heart function measurement: ['SCN10A', 'RNU1-88P - Y_RNA', 'MIR6500 - C1orf185', 'KLF12', 'LRIG1', 'SLC25A26', 'GOSR2', 'SCN5A - SCN10A', 'SCN5A', 'TBX5', 'ZNF619P1 - HMGN1P19', 'LNCAROD', 'LINC01924 - LINC01916', 'LINC01934', 'RNF19A', 'MIR4679-2 - CH25H', 'GATA4', 'PLEC', 'BAG3', 'SMARCB1', 'SLC35F1 - CEP85L', 'CCDC141', 'SERPINB9 - SERPINB6', 'CLCNKA', 'CASQ2', 'TTN-AS1', 'CWC27', 'LINC00964', 'ALPK3']
# Genes: 29
#
# Proteins: 18
#
# Number of edges: 6
#
# P-value: 3.16e-06
# post-traumatic stress disorder EFO_0001358
# ...
# Genes: 76
#
# Proteins: 44
#
# Number of edges: 3
#
# P-value: 0.1061
# Waldenstrom macroglobulinemia EFO_0009441
# Genes mapped to Waldenstrom macroglobulinemia: ['IRF4 - EXOC2', 'LINC02318 - TCL6', 'SYNE3']
# Genes: 3
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 8.63e-08
# response to radiation, radiation-induced brain injury EFO_0009704
# Genes mapped to response to radiation, radiation-induced brain injury: ['CEP128']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 44
#
# P-value: 2.89e-15
# Anti-rubella virus IgG measurement EFO_0009357
# Genes mapped to Anti-rubella virus IgG measurement: ['GRM8']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 5
#
# P-value: 0.3719
# peptic ulcer disease MONDO_0004247
# Genes mapped to peptic ulcer disease: ['FUT2', 'PSCA', 'JRK', 'CNGA4 - CCKBR', 'MUC1', 'MUC6', 'EIF1 - GAST', 'ABO', 'URAD', 'CERKL', 'PLCL2', 'MECOM', 'LINC01091', 'SND1', 'ZNF169', 'SEC1P - FUT2', 'NHEJ1', 'TTC33', 'F12', 'GRK6', 'AKAP7', 'SLC22A3', 'PSCA - LY6K', 'MIR4291 - BARX1', 'GNAS', 'RGS19', 'GGT1', 'UBQLN4']
# Genes: 28
#
# Proteins: 22
#
# Number of edges: 3
#
# P-value: 0.0047
# Candidemia EFO_1001282
# Genes mapped to Candidemia: ['LINC01344', 'SKIC2', 'OBI1-AS1', 'RPL15P2 - LINC02279', 'SPTBN5', 'THRAP3P2 - SLCO3A1', 'Y_RNA - LINC01896', 'RBFOX2 - APOL3']
# Genes: 8
#
# Proteins: 1
#
# Number of edges: 50
#
# P-value: 0.0
# geographic atrophy lesion growth EFO_0010080
# Genes mapped to geographic atrophy lesion growth: ['LINC01677 - MTATP6P14', 'FTCD', 'DISC1FP1']
# Genes: 3
#
# Proteins: 1
#
# Number of edges: 37
#
# P-value: 7.19e-11
# renal overload-type gout EFO_0021525
# Genes mapped to renal overload-type gout: ['ABCG2', 'SPATA31C2 - RPSAP49', 'RN7SL318P - RPL23AP54']
# Genes: 3
#
# Proteins: 1
#
# Number of edges: 18
#
# P-value: 0.0199
# hemorrhoid EFO_0009552
# Genes mapped to hemorrhoid: ['LINC02811', 'TRIM59', 'RNA5SP74 - LRRN2', 'LYPLAL1-AS1 - ZC3H11B', 'GDF7', 'BIRC6 - TTC27', 'FEZ2', 'BMPR1B', 'TET2', 'LINC02831 - LINC01812', 'MERTK', 'TEX41', 'KRT18P51 - HHIP-AS1', 'ITGB6', 'MAP3K20', 'FBXL7', 'NEMP2-DT - NAB1', 'C3orf20 - LINC02011', 'SFMBT1', 'RNU6-281P - FOXP1', 'PHLDB2', 'PLCXD2', 'ZBTB20', 'LINC03000 - LINC01938', 'EXOC2', 'GMDS', 'RBM24 - CAP2', 'RNF39 - TRIM31', 'DCBLD1', 'TARID', 'ESR1', 'LINC02468 - PDE3A-AS1', 'SOX5', 'KNOP1P1 - RN7SL38P', 'HDAC7', 'HOTAIR', 'HMGA2 - MIR6074', 'LINC02459 - TBX5', 'DLEU1', 'RNASEH2B-AS1', 'GREM1', 'SMAD3', 'PIAS1', 'LINC00924 - RNU2-3P', 'MYH11', 'FOXL1 - LINC02188', 'TP53', 'MAP2K4 - LINC00670', 'MYO15A', 'NF1', 'RNA5SP444 - PRKCA', 'SPC24', 'ZNF283 - ZNF404', 'RBM38 - HMGB1P1', 'MIR646HG', 'LINC00189', 'BACH1', 'AP1B1', 'THBS2', 'THBS2-AS1', 'SUGCT', 'EGFR', 'TMEM270 - ELN', 'MUC12', 'FAM185A', 'SND1', 'AGPAT5 - XKR5', 'CCAR2', 'XKR9', 'ZFHX4-AS1', 'CCDC26 - MTRF1LP2', 'PLEC', 'CDKN2B-AS1', 'BICD2', 'PAPPA - ASTN2', 'ABO', 'KIAA1217', 'CTBP2', 'AMPD3', 'IRAG1', 'MTCH2', 'ANO1', 'LINC02763 - NCAM1', 'CLMP', 'LEKR1 - LINC00880', 'SLC44A3-AS1', 'ATP1B1', 'ACOX3', 'LIAS - UGDH', 'AREG - BTC', 'SRBD1', 'EHBP1', 'SERTAD2', 'LINC01091', 'TMEM248P1 - LINC02379', 'ACVR2A', 'TPPP', 'HOXD11', 'COL5A2 - KRT18P19', 'HMGB1P47 - RNA5SP182', 'KIAA0825', 'MTCO1P24 - CTBP2P4', 'SRPX', 'TDGF1P3 - M6PRP1', 'LMO7', 'FRMD4A', 'PRPF18']
# Genes: 107
#
# Proteins: 60
#
# Number of edges: 20
#
# P-value: 0.00021
# metabolic disease EFO_0000589
# Genes mapped to metabolic disease: ['CARMIL1']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 20
#
# P-value: 0.00032
# hypertensive nephropathy MONDO_0024633
# Genes mapped to hypertensive nephropathy: ['CRIPT - LINC01118', 'PCDH10 - PABPC4L', 'LINC00421 - PARP4P2', 'FKBP3']
# Genes: 4
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.004
# Mycobacterium avium complex disease EFO_0007386
# Genes mapped to Mycobacterium avium complex disease: ['CHP2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 2
#
# P-value: 0.5268
# familial hyperlipidemia MONDO_0001336
# Genes mapped to familial hyperlipidemia: ['LPL - RPL30P9', 'UBXN2B - CYP7A1', 'TRIB1AL', 'ASAH2B', 'A1CF', 'CYP26A1 - NIP7P1', 'RPL15P15 - LINC02151', 'LINC02702', 'ZPR1', 'PAFAH1B2', 'GAS6', 'GAS6-AS1', 'CATSPER2P1', 'LIPC', 'ALDH1A2', 'LIPC-AS1', 'DHX38', 'CMIP', 'CFAP97D1 - MPP3', 'ANGPTL4', 'SLC44A2', 'LDLR', 'SUGP2', 'TM6SF2', 'CILP2 - PBX4', 'BCL3', 'APOE - APOC1', 'RELB', 'ERCC1', 'POLR1G', 'VEGFA - LINC02537', 'GSTA12P', 'LPA', 'FKBP6 - Y_RNA', 'MLXIPL', 'KLF14 - LINC-PINT', 'CSGALNACT1 - INTS10', 'SMARCA4 - LDLR', 'CEACAM16-AS1', 'CBLC - BCAM', 'MAMSTR', 'PLTP', 'OPRL1', 'NAT2', 'APOE', 'LINC01370 - MAFB', 'ARID1A', 'PCSK9', 'DOCK7', 'ELAPOR1', 'CELSR2', 'ATXN7L2', 'LINC00184 - LINC01132', 'LINC02850 - APOB', 'TDRD15 - NUTF2P8', 'GCKR', 'BABAM2', 'ABCG8', 'COBLL1', 'NYAP2 - MIR5702', 'HGFAC', 'AFF1', 'TIMD4 - HAVCR1', 'HLA-C - USP8P1', 'ATG4C - LINC01739', 'GALNT2', 'PPM1G', 'ZNF512 - CCDC121', 'C5orf67', 'TRIB1 - TRIB1AL', 'APOC1 - APOC1P1', 'HMGCR', 'CERT1', 'TIMD4', 'NCR3 - UQCRHP1', 'TSBP1-AS1 - HLA-DRA', 'HLA-DRB1 - HLA-DQA1', 'IGF2R', 'SLC22A2 - SLC22A3']
# Genes: 79
#
# Proteins: 44
#
# Number of edges: 19
#
# P-value: 5.77e-15
# Rubella virus seropositivity EFO_0009344
# Genes mapped to Rubella virus seropositivity: ['IGHV3-62 - IGHVII-62-1', 'SLC20A1P1', 'IGHV3-72 - IGHV3-73', 'KIAA1217']
# Genes: 4
#
# Proteins: 1
#
# Number of edges: 2
#
# P-value: 0.5278
# age of onset of stroke disorder OBA_2040155
# Genes mapped to age of onset of stroke disorder: ['APOE']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 43
#
# P-value: 1.2e-13
# acute myocardial infarction EFO_0008583
# Genes mapped to acute myocardial infarction: ['SLC22A3']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 7
#
# P-value: 0.3994
# psychiatric disorder MONDO_0002025
# Genes mapped to psychiatric disorder: ['COL22A1 - KCNK9', 'PRKCE']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 19
#
# P-value: 0.0177
# peripheral vascular disease EFO_0003875
# Genes mapped to peripheral vascular disease: ['SULT2A1 - BSPH1', 'HIPK3 - KIAA1549L', 'F5', 'LINC02930', 'CSTPP1']
# Genes: 5
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 1.08e-07
# Zika virus congenital syndrome MONDO_0000890
# Genes mapped to Zika virus congenital syndrome: ['DISP3']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 3
#
# P-value: 0.2106
# serum lipopolysaccharide activity EFO_0600064
# Genes mapped to serum lipopolysaccharide activity: ['HRG-AS1', 'KNG1', 'KLKB1', 'F12', 'GRK6', 'MIR130AHG', 'ALDH1A2']
# Genes: 7
#
# Proteins: 5
#
# Number of edges: 3
#
# P-value: 3.81e-06
# pelvis bone mineral density EFO_0020104
# Genes mapped to pelvis bone mineral density: ['SFRP4']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 30
#
# P-value: 3.96e-07
# lysophosphatidylcholine 16:0 measurement EFO_0010357
# Genes mapped to lysophosphatidylcholine 16:0 measurement: ['GCKR', 'RNA5SP279 - SMARCA2']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 16
#
# P-value: 0.0233
# bacterial disease EFO_0000771
# Genes mapped to bacterial disease: ['BIRC6']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 32
#
# P-value: 5.72e-08
# C34:2 phosphatidylethanolamine measurement EFO_0801132
# Genes mapped to C34:2 phosphatidylethanolamine measurement: ['ALDH1A2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 9.84e-08
# C36:2 phosphatidylethanolamine measurement EFO_0801136
# Genes mapped to C36:2 phosphatidylethanolamine measurement: ['ALDH1A2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 9.84e-08
# C38:4 phosphatidylethanolamine measurement EFO_0801143
# Genes mapped to C38:4 phosphatidylethanolamine measurement: ['ALDH1A2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 9.84e-08
# response to statin, muscle tissue disorder MONDO_0003939
# Genes mapped to response to statin, muscle tissue disorder: ['TMEM9', 'LINC01742 - CIMIP1', 'GALNT13-AS1 - RNA5SP107', 'LINC02997 - RNU6-1232P', 'RNU6-715P - RNA5SP106', 'LINC02712']
# Genes: 6
#
# Proteins: 1
#
# Number of edges: 6
#
# P-value: 0.0522
# Diarrhea, Infantile, Astroviridae infectious disease EFO_0007158
# Genes mapped to Diarrhea, Infantile, Astroviridae infectious disease: ['RPLP0P4 - LORICRIN', 'PRLHR']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 7
#
# P-value: 0.24
# phosphatidylcholine 28:0 measurement EFO_0021466
# Genes mapped to phosphatidylcholine 28:0 measurement: ['ADAMTSL3']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 16
#
# P-value: 0.00051
# phosphatidylcholine 33:0 measurement EFO_0021468
# Genes mapped to phosphatidylcholine 33:0 measurement: ['FADS2', 'KCNMB4 - RNU4-65P']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.00036
# phosphatidylcholine 40:7 measurement EFO_0021477
# Genes mapped to phosphatidylcholine 40:7 measurement: ['SUGP1', 'ADAM23', 'FADS1', 'FADS2', 'MOGAT2 - RN7SL786P', 'NOMO1', 'NPIPA1 - PDXDC1', 'PDXDC1', 'RRN3']
# Genes: 9
#
# Proteins: 7
#
# Number of edges: 2
#
# P-value: 2.17e-05
# lysophosphatidylcholine 22:5 measurement EFO_0021462
# Genes mapped to lysophosphatidylcholine 22:5 measurement: ['FADS1', 'FADS2', 'ELOVL2', 'MYRF', 'TMEM258', 'RPSAP1 - NFATC2', 'ELOVL2-AS1', 'RNU6-543P - NRBF2', 'RPLP0P2 - DAGLA']
# Genes: 9
#
# Proteins: 5
#
# Number of edges: 2
#
# P-value: 4.55e-06
# lysophosphatidylcholine 26:0 measurement EFO_0021464
# Genes mapped to lysophosphatidylcholine 26:0 measurement: ['FADS2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.00036
# lysophosphatidylcholine 19:0 measurement EFO_0021455
# Genes mapped to lysophosphatidylcholine 19:0 measurement: ['KRT8P37 - CHCHD3P1', 'PKD2L1 - SCD', 'GABRA6']
# Genes: 3
#
# Proteins: 1
#
# Number of edges: 38
#
# P-value: 1.83e-11
# lysophosphatidylcholine 17:1 measurement EFO_0021453
# Genes mapped to lysophosphatidylcholine 17:1 measurement: ['PKD2L1', 'LNCRNA-IUR - FAM76B']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 15
#
# P-value: 0.0429
# lysophosphatidylcholine 20:0 measurement EFO_0021456
# Genes mapped to lysophosphatidylcholine 20:0 measurement: ['APOE']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 43
#
# P-value: 1.2e-13
# esophageal disease EFO_0009544
# Genes mapped to esophageal disease: ['CTNNA3', 'LINC00917 - FENDRR', 'DDX52 - HNF1B']
# Genes: 3
#
# Proteins: 1
#
# Number of edges: 40
#
# P-value: 3e-11
# age of onset of cervical dystonia OBA_2040167
# Genes mapped to age of onset of cervical dystonia: ['GABBR2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 39
#
# P-value: 2.32e-11
# pigment dispersion syndrome, pigmentary glaucoma EFO_0021425
# Genes mapped to pigment dispersion syndrome, pigmentary glaucoma: ['GSAP - GCNT1P5', 'GRM5']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.00046
# actinic keratosis EFO_0002496
# Genes mapped to actinic keratosis: ['FOXP1', 'SLC45A2', 'HLA-DQA1', 'IRF4', 'TRPS1', 'BNC2 - RN7SL720P', 'TYR', 'HERC2', 'DEF8', 'RALY', 'MMP24OS', 'MMP24', 'SPATA33']
# Genes: 13
#
# Proteins: 12
#
# Number of edges: 2
#
# P-value: 0.00076
# bruxism MONDO_0002443
# Genes mapped to bruxism: ['MYO3B']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 55
#
# P-value: 0.0
# color vision disorder MONDO_0001703
# Genes mapped to color vision disorder: ['AMZ1', 'NRF1', 'SFRP4 - STARD3NL', 'ZNF775', 'RABGEF1', 'SEMA3D', 'SMIM30 - PPP1R3A', 'ATP6V0A4', 'AHR', 'EEPD1', 'EIF3B', 'LRRC61', 'RNF32-DT', 'COL26A1', 'SDK1', 'CPVL', 'CDCA7L - RAPGEF5', 'AASS', 'RAB19', 'ELDR', 'SPMIP7 - IKZF1', 'GN
LINC01982', 'MAP2K4 - LINC00670', 'NDEL1', 'ULK2', 'AKAP1 - MSI2', 'INO80C - GALNT1', 'MC5R', 'LINC01924 - LINC01916', 'ATP9B', 'SETBP1 - SLC14A2', 'LINC01901 - LINC01477', 'RPL12P40 - RN7SKP182', 'ZNF521 - RN7SL97P', 'DLGAP1', 'LINC02429 - Y_RNA', 'LINC02273 - RN7SL446P', 'EPHA5-AS1', 'SCLT1', 'C1QTNF7-AS1', 'MARK2P11 - LINC02227', 'CWC27', 'GABRA6', 'COMMD10', 'AP3B1', 'LINC01863 - LINC01942', 'PDZD2', 'CTD-2194D22.4 - Y_RNA', 'LINC01938 - RN7SKP60', 'ATP6AP1L - RPL5P16', 'PDE4D', 'GUSBP1 - CDH12', 'FGF18 - SMIM23', 'GABRG2 - RNU6-164P', 'PCBP2P3 - LDHBP3', 'FAT2', 'ATP6V0E1', 'RNU6-699P - RNU1-63P', 'ABCG2 - PPM1K', 'SMIM20 - LINC02357', 'GAPDHP56 - RNU6-224P', 'HPSE - HELQ', 'KRT19P6 - PMPCAP1', 'ADH7', 'LINC02616 - MIR4801', 'MARCHF1', 'LINC02172 - LINC00616', 'RNA5SP169 - LINC02273', 'RNA5SP173 - NDUFB5P1', 'STAP1', 'GRXCR1 - LINC02383', 'RPS3AP17 - PCDH7', 'PCGF3-AS1', 'GPM6A', 'RHOH', 'GABRB1', 'TENM3', 'RN7SL776P - PHB1P14', 'LINC02498 - MIR572', 'LINC02233 - LINC02477', 'STPG2', 'CENPC - STAP1', 'LINC01500', 'EGLN3', 'FBXO33 - LINC02315', 'BNIP3P1 - RPL26P3', 'CHD8', 'LINC02325', 'EXOC5', 'DNAJC8P1 - RPS3AP4', 'LINC02304 - LINC02325', 'RNU6-189P - Metazoa_SRP', 'GCH1', 'MTA1', 'OR7K1P - LINC02306', 'RGS6', 'DDHD1-DT - RPS3AP46', 'HYKK', 'LINC03080', 'INSYN1-AS1 - TBC1D21', 'Y_RNA - GOLGA8UP', 'WDR73', 'PLIN1', 'RYR3', 'FBN1', 'GRIN2B - MRPS18CP4', 'MIR3685 - RNU6-735P', 'RASSF8', 'ACSS3', 'ASCL4 - WSCD2', 'IFITM3P2 - H3-5', 'RNU1-117P - LINC02458', 'UNG', 'TBX3-AS1 - UBA52P7', 'SETD1B', 'FARP1', 'LINC00343 - RNA5SP38', 'GYG1P2 - RNU6-67P', 'LINC00351 - SLITRK6', 'PCDH8 - OLFM4', 'DAOA-AS1 - LINC00343', 'TPP2', 'LINC01038 - LINC00382', 'SUCLA2', 'RPL29P29 - LINC00433', 'MTIF3 - RNU6-63P', 'ATP6V1G1P7 - RPL7P45', 'LINC00551', 'GPC5', 'TBATA', 'FRMPD2 - RPS6 ...
# Genes: 1254
#
# Proteins: 561
#
# Number of edges: 269
#
# P-value: 0.0
# arthritis EFO_0005856
# Genes mapped to arthritis: ['SHANK3', 'BCO1 - GAN']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 54
#
# P-value: 0.0
# anemia MONDO_0002280
# Genes mapped to anemia: ['TSPOAP1-AS1', 'RNF43']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 23
#
# P-value: 0.00032
# psoriasis 14, pustular MONDO_0013626
# Genes mapped to psoriasis 14, pustular: ['IL36RN']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 32
#
# P-value: 4.21e-08
# nontoxic goiter MONDO_0001658
# Genes mapped to nontoxic goiter: ['FMN2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 6
#
# P-value: 0.3864
# essential hypertension MONDO_0001134
# Genes mapped to essential hypertension: ['KCNK3', 'PRDM8 - FGF5']
# Genes: 2
#
# Proteins: 1
#
# Number of edges: 25
#
# P-value: 5.16e-05
# breast cyst EFO_1000848
# Genes mapped to breast cyst: ['CACNA1D']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 31
#
# P-value: 1.92e-06
# rib fracture EFO_0009620
# Genes mapped to rib fracture: ['TENM2']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 7
#
# P-value: 0.1091
# hyperplasia EFO_0000536
# Genes mapped to hyperplasia: ['LINC02794', 'B3GLCT - RXFP2', 'NDP-AS1', 'NDP']
# Genes: 4
#
# Proteins: 1
#
# Number of edges: 28
#
# P-value: 1.32e-05
# esophageal ulcer MONDO_0044782
# Genes mapped to esophageal ulcer: ['CRLF1']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 12
#
# P-value: 0.0204
# familial hemolytic anemia MONDO_0003689
# Genes mapped to familial hemolytic anemia: ['HBB']
# Genes: 1
#
# Proteins: 1
#
# Number of edges: 36
#
# P-value: 2.26e-10

# %%
print(cancers)
# Out:
# [{'name': 'carrier status, prostate carcinoma', 'efo_id': 'EFO_0001663', 'num_edges': 42, 'z_score': 2.272683867591024, 'pvalue': '7.05e-14'}, {'name': 'esophageal carcinoma', 'efo_id': 'EFO_0002916', 'num_edges': 3, 'z_score': 4.7654566532944, 'pvalue': '0.0819'}, {'name': 'squamous cell carcinoma', 'efo_id': 'EFO_0000707', 'num_edges': 26, 'z_score': 7.869171484068971, 'pvalue': '8.39e-08'}, {'name': 'lung adenocarcinoma', 'efo_id': 'EFO_0000571', 'num_edges': 32, 'z_score': 6.520595269065408, 'pvalue': '2.11e-06'}, {'name': 'multiple myeloma', 'efo_id': 'EFO_0001378', 'num_edges': 15, 'z_score': 6.40288775120254, 'pvalue': '2.35e-05'}, {'name': 'myeloproliferative disorder', 'efo_id': 'EFO_0004251', 'num_edges': 11, 'z_score': 18.86437411412275, 'pvalue': '3.2e-05'}, {'name': 'non-small cell lung carcinoma', 'efo_id': 'EFO_0003060', 'num_edges': 5, 'z_score': 2.7720134932161673, 'pvalue': '0.032'}, {'name': 'triple-negative breast cancer', 'efo_id': 'EFO_0005537', 'num_edges': 3, 'z_score': 6.693768576159009, 'pvalue': '1.0'}, {'name': 'mammographic density measurement', 'efo_id': 'EFO_0005941', 'num_edges': 2, 'z_score': 2.7353835321409803, 'pvalue': '0.5139'}, {'name': 'estrogen receptor status', 'efo_id': 'EFO_0005512', 'num_edges': 16, 'z_score': 0.1917746886407855, 'pvalue': '0.0762'}, {'name': 'endometrial carcinoma', 'efo_id': 'EFO_1001512', 'num_edges': 5, 'z_score': 4.211228271041064, 'pvalue': '0.0153'}, {'name': 'squamous cell lung carcinoma', 'efo_id': 'EFO_0000708', 'num_edges': 40, 'z_score': 8.776251205997267, 'pvalue': '2.29e-09'}, {'name': 'gastric carcinoma', 'efo_id': 'EFO_0000178', 'num_edges': 5, 'z_score': 4.126013174560404, 'pvalue': '0.00023'}, {'name': 'estrogen-receptor negative breast cancer', 'efo_id': 'EFO_1000650', 'num_edges': 19, 'z_score': 11.563891598959335, 'pvalue': '0.0003'}, {'name': 'cervical carcinoma', 'efo_id': 'EFO_0001061', 'num_edges': 11, 'z_score': 6.1758000639776265, 'pvalue': '5.5e-06'}, {'name': 'pancreatic carcinoma', 'efo_id': 'EFO_0002618', 'num_edges': 16, 'z_score': 3.141237671830124, 'pvalue': '0.00027'}, {'name': 'gastric cardia carcinoma', 'efo_id': 'EFO_1001252', 'num_edges': 52, 'z_score': 1.9504111211186872, 'pvalue': '0.0'}, {'name': 'age at onset, glioblastoma multiforme', 'efo_id': 'EFO_0000519', 'num_edges': 3, 'z_score': 38.76885534638875, 'pvalue': '0.112'}, {'name': 'ovarian carcinoma', 'efo_id': 'EFO_0001075', 'num_edges': 62, 'z_score': 5.755376360623383, 'pvalue': '0.0365'}, {'name': 'ovarian clear cell adenocarcinoma', 'efo_id': 'EFO_1000042', 'num_edges': 27, 'z_score': 0.7425465800193993, 'pvalue': '7.61e-06'}, {'name': 'ovarian endometrioid carcinoma', 'efo_id': 'EFO_1001515', 'num_edges': 3, 'z_score': 6.863838256788907, 'pvalue': '7.61e-06'}, {'name': 'hepatocyte growth factor measurement', 'efo_id': 'EFO_0006903', 'num_edges': 2, 'z_score': 3.7074450403234795, 'pvalue': '0.059'}, {'name': 'lymphocyte percentage of leukocytes', 'efo_id': 'EFO_0007993', 'num_edges': 270, 'z_score': 14.39626489238164, 'pvalue': '0.0'}, {'name': 'hepatocellular carcinoma', 'efo_id': 'EFO_0000182', 'num_edges': 2, 'z_score': 3.8876804490909262, 'pvalue': '0.0955'}, {'name': 'basal cell carcinoma', 'efo_id': 'EFO_0004193', 'num_edges': 45, 'z_score': 7.2671325143210215, 'pvalue': '2.39e-11'}, {'name': 'family history of lung cancer', 'efo_id': 'EFO_0006953', 'num_edges': 3, 'z_score': 0.8151248695372575, 'pvalue': '3.38e-13'}, {'name': 'keratinocyte carcinoma', 'efo_id': 'EFO_0010176', 'num_edges': 18, 'z_score': 12.718638810382817, 'pvalue': '2.38e-06'}, {'name': 'cutaneous melanoma', 'efo_id': 'EFO_0000389', 'num_edges': 83, 'z_score': 18.060805840336954, 'pvalue': '0.0'}, {'name': 'Uveal Melanoma', 'efo_id': 'EFO_1000616', 'num_edges': 3, 'z_score': 4.826779847018268, 'pvalue': '0.0179'}, {'name': 'malignant epithelial tumor of ovary', 'efo_id': 'MONDO_0018364', 'num_edges': 2, 'z_score': 5.185980305342686, 'pvalue': '0.0207'}, {'name': 'non-melanoma skin carcinoma', ...

# %%
print(len(noncancers))
# Out:
# 446

# %%
import csv

def write_to_csv(filename, data):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=list(data[0].keys()))
        writer.writeheader()
        writer.writerows(data)

# %%
write_to_csv("cancerous_final.csv", cancers)

# %%
write_to_csv("noncancerous_final.csv", noncancers)
